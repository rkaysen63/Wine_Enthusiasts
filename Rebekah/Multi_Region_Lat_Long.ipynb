# %%
# Dependencies to pull API
import requests
import json
# Google developer API key
from config import gkey

# %%
# Import Dependencies for Database
from config import password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import psycopg2
import pandas as pd
import time

# %%
# Read in csv
location_wine_df = pd.read_csv("US_wine_data.csv")

# %%
# Display df columns
location_wine_df.columns
# Out:
# Index(['description', 'points', 'price', 'province', 'region_1', 'region_2',
#        'title', 'variety', 'winery', 'price_bins'],
#       dtype='object')

# %%
# Drop unnecessary columns and duplicates
region_df = location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
       'region_2', 'title', 'variety', 'winery','price_bins'], axis = 1)
region_df = region_df.drop_duplicates()

# %%
# Create a region list
region_list = list(region_df['region_1'])
region_list
# Out:
# ['Willamette Valley',
#  'Lake Michigan Shore',
#  'Napa Valley',
#  'Alexander Valley',
#  'Central Coast',
#  'Virginia',
#  'Oregon',
#  'Paso Robles',
#  'Sonoma Coast',
#  'Clarksburg',
#  'Dry Creek Valley',
#  'Sonoma Valley',
#  'McMinnville',
#  'Lake County',
#  'Monticello',
#  'North Coast',
#  'Columbia Valley (WA)',
#  'Santa Ynez Valley',
#  'California',
#  'Howell Mountain',
#  'Calistoga',
#  'Eola-Amity Hills',
#  'Ancient Lakes',
#  'Knights Valley',
#  'Sonoma County',
#  'Finger Lakes',
#  'Santa Clara Valley',
#  'Yountville',
#  'Rockpile',
#  'Santa Lucia Highlands',
#  'Spring Mountain District',
#  'Monterey',
#  'Carmel Valley',
#  'Santa Cruz Mountains',
#  'Edna Valley',
#  'Russian River Valley',
#  'Arroyo Seco',
#  'Anderson Valley',
#  'Nevada County',
#  'Cayuga Lake',
#  'Santa Barbara County',
#  'Diamond Mountain District',
#  'Mendocino',
#  'Sonoma Mountain',
#  'Amador County',
#  'St. Helena',
#  'Cole Ranch',
#  'Santa Maria Valley',
#  'Dundee Hills',
#  'Arroyo Grande Valley',
#  'Mendocino County',
#  'Rutherford',
#  'Walla Walla Valley (WA)',
#  'New York',
#  'North Fork of Long Island',
#  'Wahluke Slope',
#  'Templeton Gap District',
#  'Snipes Mountain',
#  'Long Island',
#  'Carneros',
#  'Ribbon Ridge',
#  'Red Mountain',
#  'Sta. Rita Hills',
#  'El Dorado',
#  'Suisun Valley',
#  'Lodi',
#  'Yakima Valley',
#  'Monterey County',
#  'Chiles Valley',
#  'Calaveras County',
#  'Chehalem Mountains',
#  'Horse Heaven Hills',
#  'Umpqua Valley',
#  'Ballard Canyon',
#  'Green Valley',
#  'Sierra Foothills',
#  'Yolo County',
#  'Washington',
#  'Columbia Gorge (WA)',
#  'Oak Knoll District',
#  'Rogue Valley',
#  'Northern Sonoma',
#  'Idaho',
#  'Mokelumne River',
#  'Los Carneros',
#  'Mount Veeder',
#  'Livermore Valley',
#  'Texas',
#  'Temecula Valley',
#  'Mendocino Ridge',
#  'Texas High Plains',
#  'Shenandoah Valley (CA)',
#  'Yorkville Highlands',
#  'Happy Canyon of Santa Barbara',
#  'Walla Walla Valley (OR)',
#  'Seneca Lake',
#  'Naches Heights',
#  'Hudson River Region',
#  'Napa-Sonoma',
#  'Bennett Valley',
#  'Paso Robles Willow Creek District',
#  'Contra Costa County',
#  'Michigan',
#  'Stags Leap District',
#  'Fair Play',
#  'Pennsylvania',
#  'Southern Oregon',
#  'Old Mission Peninsula',
#  'Dunnigan Hills',
#  'Coombsville',
#  'Oakville',
#  'America',
#  'Middleburg',
#  'Applegate Valley',
#  'San Benito County',
#  'San Luis Obispo County',
#  'Leelanau Peninsula',
#  'Outer Coastal Plain',
#  'Sonoma-Napa',
#  'Santa Barbara',
#  "Virginia's Eastern Shore",
#  'Columbia Valley (OR)',
#  'Red Hills Lake County',
#  'South Coast',
#  'Lake Erie',
#  'Potter Valley',
#  'Sonoma County-Napa County',
#  'Chalk Hill',
#  'New Jersey',
#  'Redwood Valley',
#  'Cucamonga Valley',
#  'Fiddletown',
#  'Augusta',
#  'New Mexico',
#  'Nevada',
#  'Paicines',
#  'Placer County',
#  'Napa County-Sonoma County',
#  'Solano County',
#  'Adelaida District',
#  'Chalone',
#  'Columbia Gorge (OR)',
#  'Lake Chelan',
#  'Rattlesnake Hills',
#  'El Dorado County',
#  'Napa County',
#  'Marin County',
#  'Fort Ross-Seaview',
#  'Mt. Harlan',
#  'Cienega Valley',
#  'Temecula',
#  'Grand Valley',
#  'Colorado',
#  'Cochise County',
#  'Pine Mountain-Cloverdale Peak',
#  'Big Valley District-Lake County',
#  'San Antonio Valley',
#  'Sierra Pelona Valley',
#  'San Luis Obispo',
#  'Atlas Peak',
#  'High Valley',
#  'San Bernabe',
#  'Ben Lomond Mountain',
#  'Missouri',
#  'Southeastern New England',
#  'Grand River Valley',
#  'Sonoita',
#  'The Hamptons, Long Island',
#  'Shenandoah Valley',
#  'Santa Barbara-Monterey',
#  'Napa-Carneros',
#  'Illinois',
#  'Malibu-Newton Canyon',
#  'Mount Harlan',
#  'Sonoma-Napa-Mendocino',
#  'San Francisco Bay',
#  'Chelan County',
#  'California Other',
#  'Saddle Rock-Malibu',
#  'Moon Mountain District Sonoma County',
#  'Humboldt County',
#  'Napa-Sonoma-Marin',
#  'Santa Clara County',
#  'Puget Sound',
#  'Solano County Green Valley',
#  'California-Oregon',
#  'Clear Lake',
#  'Guenoc Valley',
#  'Napa County-Sonoma County-San Joaquin County',
#  'Washington-Oregon',
#  'Carneros-Napa Valley',
#  'Swan Creek',
#  'El Pomar District',
#  'Tuolumne County',
#  'Santa Margarita Ranch',
#  'Malibu Coast',
#  'McDowell Valley',
#  'Yadkin Valley',
#  'Iowa',
#  'Elkton Oregon',
#  'Napa-Mendocino-Sonoma-Marin',
#  'Monterey-Santa Barbara',
#  'Sonoma County-Monterey County-Napa County',
#  'Sonoma-Mendocino',
#  'Alta Mesa',
#  'Kelsey Bench-Lake County',
#  'San Lucas',
#  'Sonoma County-Lake County',
#  'Ohio',
#  'Paso Robles Highlands District',
#  'Sonoma County-Monterey County',
#  'Vermont',
#  'Ventura County',
#  'Mendocino-Lake',
#  'Monterey-Santa Cruz',
#  'North Carolina',
#  'York Mountain',
#  'Columbia Valley-Walla Walla Valley',
#  'Madera',
#  'Sonoma',
#  'Kentucky',
#  'Clements Hills',
#  'Sonoma County-San Joaquin County',
#  'San Francisco Bay-Livermore Valley',
#  'Western Connecticut Highlands',
#  'River Junction',
#  'Monterey-Santa Barbara-Sonoma',
#  'Columbia Valley',
#  'Lake County-Mendocino County',
#  'Oregon Other',
#  'Sonoma County-Monterey County-Santa Barbara County',
#  'Yamhill County',
#  'Mendocino-Lake County-Napa',
#  'Monterey-San Luis Obispo-Santa Barbara',
#  'Tehama County',
#  'Ramona Valley',
#  'Napa County-Lake County',
#  'Arizona',
#  'Napa',
#  'Central Valley',
#  'Napa-Monterey-Mendocino',
#  'Lime Kiln Valley',
#  'Amador-Napa',
#  'Polk County',
#  'Monterey County-Napa County-Sonoma County',
#  'Antelope Valley of the California High Desert',
#  'Napa Valley-Paso Robles',
#  'Lake County-Sonoma County',
#  'Mendocino-Amador',
#  'Napa-Amador',
#  'Napa County-Sonoma County-Lake County',
#  'Santa Cruz County',
#  'Sonoma-Santa Barbara-Mendocino',
#  'Napa-Mendocino-Sonoma',
#  'Massachusetts',
#  'Lake-Sonoma-Napa',
#  'Isle St. George',
#  'Texoma',
#  'Capay Valley',
#  'Sonoma-Napa-Monterey',
#  'Hawaii',
#  'Monterey County-Napa County',
#  'San Diego County',
#  'Niagara Escarpment',
#  'Sonoma-Napa-Lake',
#  'Sonoma County-Santa Barbara County']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?inputtype=textquery&key='+ gkey

# %%
# Format regions to a string
regions = str(region_df)
regions.format
# Out:
# <function str.format>

# %%
# Create an empty list to hold the region data.
place_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the regions in the list.
for i, region in enumerate(region_list):

 # Group regions in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    placeid_url = valley_url + '&input='+ region
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the region.
    print(f"Processing Record {record_count} of Set {set_count} | {region}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for each of the regions.
    try:
        # Parse the JSON and retrieve data.
        region_url = requests.get(placeid_url).json()
        # Parse out the needed data.
        place_id = region_url['candidates'][0]['place_id']
        # Append the region information into place_id_data list.
        place_id_data.append({"region": region, 
                              "Place_id": place_id})

# If an error is experienced, skip the region.
    except:
        print("region not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | Willamette Valley
# Processing Record 2 of Set 1 | Lake Michigan Shore
# Processing Record 3 of Set 1 | Napa Valley
# Processing Record 4 of Set 1 | Alexander Valley
# Processing Record 5 of Set 1 | Central Coast
# Processing Record 6 of Set 1 | Virginia
# Processing Record 7 of Set 1 | Oregon
# Processing Record 8 of Set 1 | Paso Robles
# Processing Record 9 of Set 1 | Sonoma Coast
# Processing Record 10 of Set 1 | Clarksburg
# Processing Record 11 of Set 1 | Dry Creek Valley
# region not found. Skipping...
# Processing Record 12 of Set 1 | Sonoma Valley
# Processing Record 13 of Set 1 | McMinnville
# Processing Record 14 of Set 1 | Lake County
# Processing Record 15 of Set 1 | Monticello
# Processing Record 16 of Set 1 | North Coast
# Processing Record 17 of Set 1 | Columbia Valley (WA)
# Processing Record 18 of Set 1 | Santa Ynez Valley
# Processing Record 19 of Set 1 | California
# Processing Record 20 of Set 1 | Howell Mountain
# Processing Record 21 of Set 1 | Calistoga
# Processing Record 22 of Set 1 | Eola-Amity Hills
# Processing Record 23 of Set 1 | Ancient Lakes
# Processing Record 24 of Set 1 | Knights Valley
# Processing Record 25 of Set 1 | Sonoma County
# Processing Record 1 of Set 2 | Finger Lakes
# Processing Record 2 of Set 2 | Santa Clara Valley
# Processing Record 3 of Set 2 | Yountville
# Processing Record 4 of Set 2 | Rockpile
# Processing Record 5 of Set 2 | Santa Lucia Highlands
# Processing Record 6 of Set 2 | Spring Mountain District
# Processing Record 7 of Set 2 | Monterey
# Processing Record 8 of Set 2 | Carmel Valley
# Processing Record 9 of Set 2 | Santa Cruz Mountains
# Processing Record 10 of Set 2 | Edna Valley
# Processing Record 11 of Set 2 | Russian River Valley
# Processing Record 12 of Set 2 | Arroyo Seco
# Processing Record 13 of Set 2 | Anderson Valley
# Processing Record 14 of Set 2 | Nevada County
# Processing Record 15 of Set 2 | Cayuga Lake
# Processing Record 16 of Set 2 | Santa Barbara County
# Processing Record 17 of Set 2 | Diamond Mountain District
# Processing Record 18 of Set 2 | Mendocino
# Processing Record 19 of Set 2 | Sonoma Mountain
# Processing Record 20 of Set 2 | Amador County
# Processing Record 21 of Set 2 | St. Helena
# Processing Record 22 of Set 2 | Cole Ranch
# Processing Record 23 of Set 2 | Santa Maria Valley
# Processing Record 24 of Set 2 | Dundee Hills
# Processing Record 25 of Set 2 | Arroyo Grande Valley
# Processing Record 1 of Set 3 | Mendocino County
# Processing Record 2 of Set 3 | Rutherford
# Processing Record 3 of Set 3 | Walla Walla Valley (WA)
# Processing Record 4 of Set 3 | New York
# Processing Record 5 of Set 3 | North Fork of Long Island
# Processing Record 6 of Set 3 | Wahluke Slope
# Processing Record 7 of Set 3 | Templeton Gap District
# Processing Record 8 of Set 3 | Snipes Mountain
# Processing Record 9 of Set 3 | Long Island
# Processing Record 10 of Set 3 | Carneros
# Processing Record 11 of Set 3 | Ribbon Ridge
# Processing Record 12 of Set 3 | Red Mountain
# Processing Record 13 of Set 3 | Sta. Rita Hills
# Processing Record 14 of Set 3 | El Dorado
# Processing Record 15 of Set 3 | Suisun Valley
# Processing Record 16 of Set 3 | Lodi
# Processing Record 17 of Set 3 | Yakima Valley
# Processing Record 18 of Set 3 | Monterey County
# Processing Record 19 of Set 3 | Chiles Valley
# Processing Record 20 of Set 3 | Calaveras County
# Processing Record 21 of Set 3 | Chehalem Mountains
# Processing Record 22 of Set 3 | Horse Heaven Hills
# Processing Record 23 of Set 3 | Umpqua Valley
# Processing Record 24 of Set 3 | Ballard Canyon
# Processing Record 25 of Set 3 | Green Valley
# Processing Record 1 of Set 4 | Sierra Foothills
# Processing Record 2 of Set 4 | Yolo County
# Processing Record 3 of Set 4 | Washington
# Processing Record 4 of Set 4 | Columbia Gorge (WA)
# Processing Record 5 of Set 4 | Oak Knoll District
# Processing Record 6 of Set 4 | Rogue Valley
# Processing Record 7 of Set 4 | Northern Sonoma
# Processing Record 8 of Set 4 | Idaho
# Processing Record 9 of Set 4 | Mokelumne River
# Processing Record 10 of Set 4 | Los Carneros
# Processing Record 11 of Set 4 | Mount Veeder
# Processing Record 12 of Set 4 | Livermore Valley
# region not found. Skipping...
# Processing Record 13 of Set 4 | Texas
# Processing Record 14 of Set 4 | Temecula Valley
# Processing Record 15 of Set 4 | Mendocino Ridge
# Processing Record 16 of Set 4 | Texas High Plains
# Processing Record 17 of Set 4 | Shenandoah Valley (CA)
# Processing Record 18 of Set 4 | Yorkville Highlands
# Processing Record 19 of Set 4 | Happy Canyon of Santa Barbara
# Processing Record 20 of Set 4 | Walla Walla Valley (OR)
# Processing Record 21 of Set 4 | Seneca Lake
# Processing Record 22 of Set 4 | Naches Heights
# Processing Record 23 of Set 4 | Hudson River Region
# Processing Record 24 of Set 4 | Napa-Sonoma
# Processing Record 25 of Set 4 | Bennett Valley
# Processing Record 1 of Set 5 | Paso Robles Willow Creek District
# Processing Record 2 of Set 5 | Contra Costa County
# Processing Record 3 of Set 5 | Michigan
# Processing Record 4 of Set 5 | Stags Leap District
# Processing Record 5 of Set 5 | Fair Play
# Processing Record 6 of Set 5 | Pennsylvania
# Processing Record 7 of Set 5 | Southern Oregon
# Processing Record 8 of Set 5 | Old Mission Peninsula
# Processing Record 9 of Set 5 | Dunnigan Hills
# Processing Record 10 of Set 5 | Coombsville
# Processing Record 11 of Set 5 | Oakville
# Processing Record 12 of Set 5 | America
# Processing Record 13 of Set 5 | Middleburg
# Processing Record 14 of Set 5 | Applegate Valley
# Processing Record 15 of Set 5 | San Benito County
# Processing Record 16 of Set 5 | San Luis Obispo County
# Processing Record 17 of Set 5 | Leelanau Peninsula
# Processing Record 18 of Set 5 | Outer Coastal Plain
# Processing Record 19 of Set 5 | Sonoma-Napa
# Processing Record 20 of Set 5 | Santa Barbara
# Processing Record 21 of Set 5 | Virginia's Eastern Shore
# Processing Record 22 of Set 5 | Columbia Valley (OR)
# Processing Record 23 of Set 5 | Red Hills Lake County
# region not found. Skipping...
# Processing Record 24 of Set 5 | South Coast
# Processing Record 25 of Set 5 | Lake Erie
# Processing Record 1 of Set 6 | Potter Valley
# Processing Record 2 of Set 6 | Sonoma County-Napa County
# region not found. Skipping...
# Processing Record 3 of Set 6 | Chalk Hill
# Processing Record 4 of Set 6 | New Jersey
# Processing Record 5 of Set 6 | Redwood Valley
# Processing Record 6 of Set 6 | Cucamonga Valley
# Processing Record 7 of Set 6 | Fiddletown
# Processing Record 8 of Set 6 | Augusta
# Processing Record 9 of Set 6 | New Mexico
# Processing Record 10 of Set 6 | Nevada
# Processing Record 11 of Set 6 | Paicines
# Processing Record 12 of Set 6 | Placer County
# Processing Record 13 of Set 6 | Napa County-Sonoma County
# Processing Record 14 of Set 6 | Solano County
# Processing Record 15 of Set 6 | Adelaida District
# Processing Record 16 of Set 6 | Chalone
# Processing Record 17 of Set 6 | Columbia Gorge (OR)
# Processing Record 18 of Set 6 | Lake Chelan
# Processing Record 19 of Set 6 | Rattlesnake Hills
# Processing Record 20 of Set 6 | El Dorado County
# Processing Record 21 of Set 6 | Napa County
# Processing Record 22 of Set 6 | Marin County
# Processing Record 23 of Set 6 | Fort Ross-Seaview
# Processing Record 24 of Set 6 | Mt. Harlan
# Processing Record 25 of Set 6 | Cienega Valley
# Processing Record 1 of Set 7 | Temecula
# Processing Record 2 of Set 7 | Grand Valley
# Processing Record 3 of Set 7 | Colorado
# Processing Record 4 of Set 7 | Cochise County
# Processing Record 5 of Set 7 | Pine Mountain-Cloverdale Peak
# Processing Record 6 of Set 7 | Big Valley District-Lake County
# region not found. Skipping...
# Processing Record 7 of Set 7 | San Antonio Valley
# Processing Record 8 of Set 7 | Sierra Pelona Valley
# Processing Record 9 of Set 7 | San Luis Obispo
# Processing Record 10 of Set 7 | Atlas Peak
# Processing Record 11 of Set 7 | High Valley
# Processing Record 12 of Set 7 | San Bernabe
# Processing Record 13 of Set 7 | Ben Lomond Mountain
# Processing Record 14 of Set 7 | Missouri
# Processing Record 15 of Set 7 | Southeastern New England
# Processing Record 16 of Set 7 | Grand River Valley
# Processing Record 17 of Set 7 | Sonoita
# Processing Record 18 of Set 7 | The Hamptons, Long Island
# Processing Record 19 of Set 7 | Shenandoah Valley
# Processing Record 20 of Set 7 | Santa Barbara-Monterey
# region not found. Skipping...
# Processing Record 21 of Set 7 | Napa-Carneros
# Processing Record 22 of Set 7 | Illinois
# Processing Record 23 of Set 7 | Malibu-Newton Canyon
# Processing Record 24 of Set 7 | Mount Harlan
# Processing Record 25 of Set 7 | Sonoma-Napa-Mendocino
# Processing Record 1 of Set 8 | San Francisco Bay
# Processing Record 2 of Set 8 | Chelan County
# Processing Record 3 of Set 8 | California Other
# Processing Record 4 of Set 8 | Saddle Rock-Malibu
# Processing Record 5 of Set 8 | Moon Mountain District Sonoma County
# Processing Record 6 of Set 8 | Humboldt County
# Processing Record 7 of Set 8 | Napa-Sonoma-Marin
# region not found. Skipping...
# Processing Record 8 of Set 8 | Santa Clara County
# Processing Record 9 of Set 8 | Puget Sound
# Processing Record 10 of Set 8 | Solano County Green Valley
# Processing Record 11 of Set 8 | California-Oregon
# Processing Record 12 of Set 8 | Clear Lake
# Processing Record 13 of Set 8 | Guenoc Valley
# Processing Record 14 of Set 8 | Napa County-Sonoma County-San Joaquin County
# Processing Record 15 of Set 8 | Washington-Oregon
# Processing Record 16 of Set 8 | Carneros-Napa Valley
# Processing Record 17 of Set 8 | Swan Creek
# Processing Record 18 of Set 8 | El Pomar District
# Processing Record 19 of Set 8 | Tuolumne County
# Processing Record 20 of Set 8 | Santa Margarita Ranch
# Processing Record 21 of Set 8 | Malibu Coast
# Processing Record 22 of Set 8 | McDowell Valley
# Processing Record 23 of Set 8 | Yadkin Valley
# Processing Record 24 of Set 8 | Iowa
# Processing Record 25 of Set 8 | Elkton Oregon
# Processing Record 1 of Set 9 | Napa-Mendocino-Sonoma-Marin
# Processing Record 2 of Set 9 | Monterey-Santa Barbara
# region not found. Skipping...
# Processing Record 3 of Set 9 | Sonoma County-Monterey County-Napa County
# Processing Record 4 of Set 9 | Sonoma-Mendocino
# region not found. Skipping...
# Processing Record 5 of Set 9 | Alta Mesa
# Processing Record 6 of Set 9 | Kelsey Bench-Lake County
# region not found. Skipping...
# Processing Record 7 of Set 9 | San Lucas
# Processing Record 8 of Set 9 | Sonoma County-Lake County
# Processing Record 9 of Set 9 | Ohio
# Processing Record 10 of Set 9 | Paso Robles Highlands District
# Processing Record 11 of Set 9 | Sonoma County-Monterey County
# region not found. Skipping...
# Processing Record 12 of Set 9 | Vermont
# Processing Record 13 of Set 9 | Ventura County
# Processing Record 14 of Set 9 | Mendocino-Lake
# Processing Record 15 of Set 9 | Monterey-Santa Cruz
# Processing Record 16 of Set 9 | North Carolina
# Processing Record 17 of Set 9 | York Mountain
# region not found. Skipping...
# Processing Record 18 of Set 9 | Columbia Valley-Walla Walla Valley
# Processing Record 19 of Set 9 | Madera
# Processing Record 20 of Set 9 | Sonoma
# Processing Record 21 of Set 9 | Kentucky
# Processing Record 22 of Set 9 | Clements Hills
# Processing Record 23 of Set 9 | Sonoma County-San Joaquin County
# region not found. Skipping...
# Processing Record 24 of Set 9 | San Francisco Bay-Livermore Valley
# Processing Record 25 of Set 9 | Western Connecticut Highlands
# Processing Record 1 of Set 10 | River Junction
# Processing Record 2 of Set 10 | Monterey-Santa Barbara-Sonoma
# Processing Record 3 of Set 10 | Columbia Valley
# Processing Record 4 of Set 10 | Lake County-Mendocino County
# Processing Record 5 of Set 10 | Oregon Other
# Processing Record 6 of Set 10 | Sonoma County-Monterey County-Santa Barbara County
# Processing Record 7 of Set 10 | Yamhill County
# Processing Record 8 of Set 10 | Mendocino-Lake County-Napa
# region not found. Skipping...
# Processing Record 9 of Set 10 | Monterey-San Luis Obispo-Santa Barbara
# Processing Record 10 of Set 10 | Tehama County
# Processing Record 11 of Set 10 | Ramona Valley
# Processing Record 12 of Set 10 | Napa County-Lake County
# Processing Record 13 of Set 10 | Arizona
# Processing Record 14 of Set 10 | Napa
# Processing Record 15 of Set 10 | Central Valley
# Processing Record 16 of Set 10 | Napa-Monterey-Mendocino
# Processing Record 17 of Set 10 | Lime Kiln Valley
# Processing Record 18 of Set 10 | Amador-Napa
# Processing Record 19 of Set 10 | Polk County
# Processing Record 20 of Set 10 | Monterey County-Napa County-Sonoma County
# Processing Record 21 of Set 10 | Antelope Valley of the California High Desert
# Processing Record 22 of Set 10 | Napa Valley-Paso Robles
# Processing Record 23 of Set 10 | Lake County-Sonoma County
# Processing Record 24 of Set 10 | Mendocino-Amador
# region not found. Skipping...
# Processing Record 25 of Set 10 | Napa-Amador
# Processing Record 1 of Set 11 | Napa County-Sonoma County-Lake County
# region not found. Skipping...
# Processing Record 2 of Set 11 | Santa Cruz County
# Processing Record 3 of Set 11 | Sonoma-Santa Barbara-Mendocino
# Processing Record 4 of Set 11 | Napa-Mendocino-Sonoma
# Processing Record 5 of Set 11 | Massachusetts
# Processing Record 6 of Set 11 | Lake-Sonoma-Napa
# Processing Record 7 of Set 11 | Isle St. George
# Processing Record 8 of Set 11 | Texoma
# Processing Record 9 of Set 11 | Capay Valley
# Processing Record 10 of Set 11 | Sonoma-Napa-Monterey
# Processing Record 11 of Set 11 | Hawaii
# Processing Record 12 of Set 11 | Monterey County-Napa County
# region not found. Skipping...
# Processing Record 13 of Set 11 | San Diego County
# Processing Record 14 of Set 11 | Niagara Escarpment
# Processing Record 15 of Set 11 | Sonoma-Napa-Lake
# Processing Record 16 of Set 11 | Sonoma County-Santa Barbara County
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create place_id dataframe
placeid_df = pd.DataFrame(place_id_data)
placeid_df.head(10)
# Out:
#                 region                     Place_id
# 0    Willamette Valley  ChIJbezwJP6hlVQRBDL4exvIWSo
# 1  Lake Michigan Shore  ChIJbWjISvi2EIgR-XXUbfv_U1k
# 2          Napa Valley  ChIJMU8qI_lPhIARfMUQoxvSFP4
# 3     Alexander Valley  ChIJD2TljFMUhIARBOZe4vCoE7o
# 4        Central Coast  ChIJnShIABvyXIYRZF3DGodjgMQ
# 5             Virginia  ChIJzbK8vXDWTIgRlaZGt0lBTsA
# 6               Oregon  ChIJVWqfm3xuk1QRdrgLettlTH0
# 7          Paso Robles  ChIJvcTFFo_d7IAR79XMkfgilEY
# 8         Sonoma Coast  ChIJB8Hkg3mehoARNDJoq9RCScI
# 9           Clarksburg  ChIJd37rCctnSogR4EfMcM4e6V0

# %%
# Create place_id list
place_id_list = list(placeid_df['Place_id'])
place_id_list
# Out:
# ['ChIJbezwJP6hlVQRBDL4exvIWSo',
#  'ChIJbWjISvi2EIgR-XXUbfv_U1k',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJD2TljFMUhIARBOZe4vCoE7o',
#  'ChIJnShIABvyXIYRZF3DGodjgMQ',
#  'ChIJzbK8vXDWTIgRlaZGt0lBTsA',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJvcTFFo_d7IAR79XMkfgilEY',
#  'ChIJB8Hkg3mehoARNDJoq9RCScI',
#  'ChIJd37rCctnSogR4EfMcM4e6V0',
#  'ChIJI-UCgdlShIARPnjSSZd4foM',
#  'ChIJo3PJF7dOlVQRSM9F2xtwRMo',
#  'ChIJKdUvmscAD4gRZsVGNFFqkhs',
#  'ChIJxVk-0XjKRIYRpN4Q6igZogM',
#  'ChIJ91TWEw-1RIYR-SXBulV0iyk',
#  'ChIJQyqk37W1RIYRnCG26gFyqjc',
#  'ChIJH3v79pZT6YAR-MXTvZmd134',
#  'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#  'ChIJo4LFduhbhIARTBAsD475eGc',
#  'ChIJkTJxhwlDhIARQO6YM2Hiiwc',
#  'ChIJeSwhtQ9OlVQRr1RneWzpXDE',
#  'ChIJUVu5cvx4mVQRb1CuMS_kcro',
#  'ChIJqe38AQa1RIYRh8jExRIRmZc',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJS6NrAai1RIYRJWf-bmJ8Eaw',
#  'ChIJ69wnuncnhYAR4jxmM3iXoXE',
#  'ChIJ-bDD5__lhVQRuvNfbGh4QpQ',
#  'ChIJzfeI19gYllQRAdd-nffBy-E',
#  'ChIJn64e4Wu1RIYRGNdMhqJ5jNk',
#  'ChIJg3cxDPaHxVQRde0DiGnDILs',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJ6Znkhaj_WFMRWIf3FQUwa9A',
#  'ChIJ_fI5LWWsmoARS-gGEa8EBG0',
#  'ChIJNRmgFHlA6YAR9LRoUsOcDTs',
#  'ChIJE2iH7ldThIARzLXbwsD5C8w',
#  'ChIJSTKCCzZwQIYRPN4IGI8c6xY',
#  'ChIJEdB50Ih_24AR40vEqTx5JWI',
#  'ChIJ67ZzfzRNgIARZVnxHr6t1E8',
#  'ChIJj4-JMpIA_YYRHAbk1BKKwbQ',
#  'ChIJJ25lpCtnmoARSRe6Bmrznkg',
#  'ChIJ7ZPooopagYAR9n4U4o9Jyqk',
#  'ChIJCcThuvUT6YARzc7brv6SLmY',
#  'ChIJBwOnamNqolQRlUFeGjkeZrc',
#  'ChIJZaOyhSfs0IkR7MRQ5ZLpRyQ',
#  'ChIJyUnptFdil1QRG49Wjiuz6eY',
#  'ChIJ7xaFp4e1RIYRUDa60WcaeWI',
#  'ChIJOZxxaAi1RIYRe3j7KpIprWo',
#  'ChIJKzh9MGNIhIARECiBFxnNZt8',
#  'ChIJGeXB-Bfa7IARVfiQUCn-s6Y',
#  'ChIJ3QQ6ifNuhYAR4fM4Ln-yyVk',
#  'ChIJEQTKxz2qTE0Rs8liellI3Zc',
#  'ChIJz7o2jgm1RIYRi_5Y7JfjH0A',
#  'ChIJhUdA46i1RIYR8bUJ_CNh_7E',
#  'ChIJieUyHiaALYgRPbQiUEchRsI',
#  'ChIJffBbhegNxlQRyq1bp4KiPOY',
#  'ChIJGbHcO9DVH4gRLScJopdrFhE',
#  'ChIJ-xA8jVDAhIARYOH-hhbSx24',
#  'ChIJrQB7dGgGhYARh1UG9UP-YFs',
#  'ChIJf04HFA_NRIYR4BiEEOwif34',
#  'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#  'ChIJVWHbyXtttokRI_r_3GdeZaA',
#  'ChIJjV18y1V9xVQRNey4WKdjfrs',
#  'ChIJ_8VcLuc7koARQXmgrXGnQxc',
#  'ChIJX3PwOP2E7IAR9ToVLk_oEGY',
#  'ChIJr6p_--PfSk0RK-iQseQeI6Q',
#  'ChIJ7bCvgXvkwIkRWjEHNN3_Pw4',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJ1YMtb8cU6YARSHa612Q60cg',
#  'ChIJPTP6wnJFuokR2qI1yeXZsh4',
#  'ChIJQyqk37W1RIYRnCG26gFyqjc',
#  'ChIJj8lQak-0RIYR6lGgEXxo5xw',
#  'ChIJHYh0Ax3eMYgRYsbdqpOpRfM',
#  'ChIJE73iaKRwgYARCU5su-oXmZc',
#  'ChIJeReiS7IVhIAR3gplXNhPeSI',
#  'ChIJn0AAnpX7wIkRjW0_-Ad70iw',
#  'ChIJK-4fNG55gYARh9uaMCHzpOA',
#  'ChIJxe6eYrE0w4AR8OIYbSkxP_8',
#  'ChIJr2rpnolmmoARXFxc3qp4ks4',
#  'ChIJQaoLFpfQ-YgR5Auq4_2K5z4',
#  'ChIJqVKY50NQGIcRup41Yxpuv0Y',
#  'ChIJcbTe-KEKmYARs5X8qooDR88',
#  'ChIJYdTTrR0YkoARQcfiJ6VNmXc',
#  'ChIJk-ZOZm4Sm4AR8eQ1nDcJNKA',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJB_R9n88XhYAR-L8fjKYikj0',
#  'ChIJo-5SWSjR7IARXp9cdqmlAeo',
#  'ChIJU2-BGylokoARijhqgUPyedw',
#  'ChIJzfeI19gYllQRAdd-nffBy-E',
#  'ChIJiewjJFxum1QR4B1v94YWsBI',
#  'ChIJVzHjgcxKW4YRArZ3TXUc2K8',
#  'ChIJhQd-sopHmoARt9CBUcuaJB4',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJ82aOMnyhhYARHLRVUdyH0As',
#  'ChIJqScrY5WkhoARlNUv2wg3tsA',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJ9_fr2eEZkoARE_rvkQgeKQg',
#  'ChIJI74a9VJi24ARqAY4oIgOvGg',
#  'ChIJK0XprXRLW4YRZWyJ3baNsU0',
#  'ChIJt1YYm3QUQIcR_6eQSTGDVMc',
#  'ChIJ30PnwuKo14YRUhvNr6Cpals',
#  'ChIJB9lyfRj5g4ARblOcfrmkRrg',
#  'ChIJP-s5hlDSkYARr2Hy9ng7dKk',
#  'ChIJmUlcX5OKwoARog_bRXgdajw',
#  'ChIJJ8Jse77m7IARRg_vzsKQArw',
#  'ChIJzR-XJnFMW4YRXQD8BnDS6IA',
#  'ChIJ9ZyMlH-3RIYREL31FomOg7E',
#  'ChIJjRaalu6WYoYRsNaZMSGDE-w',
#  'ChIJwZQP0GRzU4cRaiTTgfLlAHk',
#  'ChIJfeMiSNXmwIcRcr1mBFnEW7U',
#  'ChIJwRr8wvXj5IkR2KB6j9lqR8g',
#  'ChIJm3RkX2m1RIYRa7ofUVcc4zQ',
#  'ChIJlw9tibqU1oYRLo9u4kwHPA8',
#  'ChIJG6mpkc6V6IkRUWCATXOJAbw',
#  'ChIJNcZLgG_ttIkRaSyg4lb5xm4',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJGSZubzgtC4gRVlkRZFCCFX8',
#  'ChIJPe2rmfci6IARPNp63LhdpgQ',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJBwohpl6bj4AREMlJ8U8PlaI',
#  'ChIJVZv5TUp_m1QRmJDpy3364Ys',
#  'ChIJf5QJFBK1RIYRjjfxZz9Z0O0',
#  'ChIJvcCvpxEj6IARX8hjBiy24HQ',
#  'ChIJH1iqDT2phYAROLQAfJJ_0J8',
#  'ChIJsVTwdfTf01QRfyaxfTR5OjQ',
#  'ChIJd_Y0eVIvkIARuQyDN0F1LBA',
#  'ChIJ4TiXsFQ-kFQRAX7WBEamkDM',
#  'ChIJHWTSAsMRhYAR7nqXk1q6deI',
#  'ChIJ6xyImq98z1QR7Gtgz6teGBA',
#  'ChIJo0BOeojtg4ARIxa_m15L_1A',
#  'ChIJiXWJGHVmhIARgRDJUsHC0z8',
#  'ChIJ31ZZ5gY-kIAR0dtYpsEqJEc',
#  'ChIJ58L9WshnlVQRK_Ybl-Gu9TM',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJyVBqxTGPYogR6m91-HuUSnE',
#  'ChIJrZOHqndEE4cR4G9TwVWzjaY',
#  'ChIJUXsaVaYxl4ARpyB7IpcuWGU',
#  'ChIJO7OVyhzx7IARKtcI0P4tfVc',
#  'ChIJP9YI-akd6IARWozqsnEtt5M',
#  'ChIJPT6XaW5HRYYRcaHTXsQyX98',
#  'ChIJd0x0EUEeUYgRH2PjRdOWPwc',
#  'ChIJGWD48W9e7ocR2VnHV0pj78Y',
#  'ChIJk6HV2GtUwVQR5Irl6J4W7QI',
#  'ChIJXVlZtySshYARTMGLqO62me8',
#  'ChIJvZ9cEKi1RIYRurdRu42k-uk',
#  'ChIJA5NXV2_LRIYRG2V8EkU7dKQ',
#  'ChIJ35Axq-hKr4YR4CvxFaiysLQ',
#  'ChIJ3Qfw6jZVgYAR6v6_SxmR4cc',
#  'ChIJwY5NtXrpNogRFtmfnDlkzeU',
#  'ChIJLaa1-xHF7IAR93WkHTQtLZk',
#  'ChIJ_87aSGzctEwRtGtUNnSJTSY',
#  'ChIJqXcAstJi6YARs7DDR_CQld0',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJSdU2fBtEjoARhfnXKksQylI',
#  'ChIJgRo4_MQfVIgRGa4i6fUwP60',
#  'ChIJJ3E3VXtqolQR8LFwW7TuTjM',
#  'ChIJA9vG_ZILlIAREGnnItpCwzY',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJyVMZi0xzQogR_N_MxU5vH3c',
#  'ChIJn5y8vLhKW4YRUDdxmXnvHf8',
#  'ChIJZQ5HN8Hnj4ARYsA5YnxIMuc',
#  'ChIJjTbUpWv_54kR1Kq8EXgm4T0',
#  'ChIJ7cXYmg0HWYYRNSyRdys_2n4',
#  'ChIJvUHEkSzkjYARem7k3ShZ7lY',
#  'ChIJIcQ99wi1RIYRDk-jP8lZ0fw',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJ3WuezxjmjYAR17wDhRQoAkk',
#  'ChIJ38wjXU1KlVQRnXojmjNOBBE',
#  'ChIJR2mFLVvljYARhYhkKw1Zbr0',
#  'ChIJ6_8ezximgoARGaPfZ5WDxqo',
#  'ChIJUdAfj5Do24ARv5f06-88kuU',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJaxhMy-sIK4cRcc3Bf7EnOUI',
#  'ChIJhSXaj5W0RIYR3V-B8qaBoa8',
#  'ChIJyZkVOx6DgoARU5w0SCOkBvY',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJL4EPzdHbt4kRyUilrlIwE00',
#  'ChIJV3SfjiVkXIYRFVb-fvmE_Rs',
#  'ChIJD0-pOcNq3YgRmOvtrrA4vjg',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJA3cgzNJDwoARX6xdvBafiAU',
#  'ChIJIcQ99wi1RIYRDk-jP8lZ0fw',
#  'ChIJkRamZgi1RIYRunh_5JKEl1Y',
#  'ChIJV3SfjiVkXIYRFVb-fvmE_Rs',
#  'ChIJfzsx1n8TjoARGbNHDCbAPhU',
#  'ChIJDYp1OaiuhYARIwCuBhIwVOs',
#  'ChIJhSXaj5W0RIYR3V-B8qaBoa8',
#  'ChIJ_b9z6W1l44kRHA2DVTbQxkU',
#  'ChIJbbN3nxlbhIARBx_wpkOFTuQ',
#  'ChIJc0hMxsz4OogRo_VKXzCAZXQ',
#  'ChIJU06mbyZpS4YRaxZrJLN9aSY',
#  'ChIJP5PWeHDphIARy2FLJhKIJjc',
#  'ChIJzxdcDVrkjYARzccwwfdSQsg',
#  'ChIJBeB5Twbb_3sRKIbMdNKCd0s',
#  'ChIJHWD_IzDr24ARKAeA6yv9DTU',
#  'ChIJ12YMXUm0AogRkMoAelhilAA',
#  'ChIJUWVAwmcGhYARBoANHIv70Os',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url2 = ('https://maps.googleapis.com/maps/api/place/details/json?&key='+ gkey)

# %%
# Create an empty list to hold the coord data.
coord_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the place ids in the list.
for i, placeids in enumerate(place_id_list):

 # Group place ids in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    coord_url = valley_url2 + '&place_id='+ placeids
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the place ids.
    print(f"Processing Record {record_count} of Set {set_count} | {placeids}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for the place ids and retrieve the lat long info.
    try:
        # Parse the JSON and retrieve data.
        geo_url = requests.get(coord_url).json()
        # Parse out the needed data.
        lat_id = geo_url['result']['geometry']['location']['lat']
        long_id = geo_url['result']['geometry']['location']['lng']
        # Append the region information into place_id_data list.
        coord_id_data.append({"Place_id": placeids, 
                              "Latitude": lat_id,
                             "Longitude": long_id})
        


# If an error is experienced, skip the record.
    except:
        print("record not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ChIJbezwJP6hlVQRBDL4exvIWSo
# Processing Record 2 of Set 1 | ChIJbWjISvi2EIgR-XXUbfv_U1k
# Processing Record 3 of Set 1 | ChIJMU8qI_lPhIARfMUQoxvSFP4
# Processing Record 4 of Set 1 | ChIJD2TljFMUhIARBOZe4vCoE7o
# Processing Record 5 of Set 1 | ChIJnShIABvyXIYRZF3DGodjgMQ
# Processing Record 22 of Set 9 | ChIJUdAfj5Do24ARv5f06-88kuU
# Processing Record 23 of Set 9 | ChIJMU8qI_lPhIARfMUQoxvSFP4
# Processing Record 24 of Set 9 | ChIJaxhMy-sIK4cRcc3Bf7EnOUI
# Processing Record 25 of Set 9 | ChIJhSXaj5W0RIYR3V-B8qaBoa8
# Processing Record 1 of Set 10 | ChIJyZkVOx6DgoARU5w0SCOkBvY
# Processing Record 2 of Set 10 | ChIJC_EH0CPkjYARQvIZ23xl6MY
# Processing Record 3 of Set 10 | ChIJL4EPzdHbt4kRyUilrlIwE00
# Processing Record 4 of Set 10 | ChIJV3SfjiVkXIYRFVb-fvmE_Rs
# Processing Record 5 of Set 10 | ChIJD0-pOcNq3YgRmOvtrrA4vjg
# Processing Record 6 of Set 10 | ChIJC_EH0CPkjYARQvIZ23xl6MY
# Processing Record 7 of Set 10 | ChIJA3cgzNJDwoARX6xdvBafiAU
# Processing Record 8 of Set 10 | ChIJIcQ99wi1RIYRDk-jP8lZ0fw
# Processing Record 9 of Set 10 | ChIJkRamZgi1RIYRunh_5JKEl1Y
# Processing Record 10 of Set 10 | ChIJV3SfjiVkXIYRFVb-fvmE_Rs
# Processing Record 11 of Set 10 | ChIJfzsx1n8TjoARGbNHDCbAPhU
# Processing Record 12 of Set 10 | ChIJDYp1OaiuhYARIwCuBhIwVOs
# Processing Record 13 of Set 10 | ChIJhSXaj5W0RIYR3V-B8qaBoa8
# Processing Record 14 of Set 10 | ChIJ_b9z6W1l44kRHA2DVTbQxkU
# Processing Record 15 of Set 10 | ChIJbbN3nxlbhIARBx_wpkOFTuQ
# Processing Record 16 of Set 10 | ChIJc0hMxsz4OogRo_VKXzCAZXQ
# Processing Record 17 of Set 10 | ChIJU06mbyZpS4YRaxZrJLN9aSY
# Processing Record 18 of Set 10 | ChIJP5PWeHDphIARy2FLJhKIJjc
# Processing Record 19 of Set 10 | ChIJzxdcDVrkjYARzccwwfdSQsg
# Processing Record 20 of Set 10 | ChIJBeB5Twbb_3sRKIbMdNKCd0s
# Processing Record 21 of Set 10 | ChIJHWD_IzDr24ARKAeA6yv9DTU
# Processing Record 22 of Set 10 | ChIJ12YMXUm0AogRkMoAelhilAA
# Processing Record 23 of Set 10 | ChIJUWVAwmcGhYARBoANHIv70Os
# Processing Record 24 of Set 10 | ChIJj7atfV0ihIAR_qYnBSATSUk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a coordinate dataframe
coord_df = pd.DataFrame(coord_id_data)
coord_df.head(10)
# Out:
#                       Place_id   Latitude   Longitude
# 0  ChIJbezwJP6hlVQRBDL4exvIWSo  44.942554 -122.933762
# 1  ChIJbWjISvi2EIgR-XXUbfv_U1k  42.220870  -86.369469
# 2  ChIJMU8qI_lPhIARfMUQoxvSFP4  38.502469 -122.265389
# 3  ChIJD2TljFMUhIARBOZe4vCoE7o  38.612965 -122.769435
# 4  ChIJnShIABvyXIYRZF3DGodjgMQ  29.444497  -98.322396
# 5  ChIJzbK8vXDWTIgRlaZGt0lBTsA  37.431573  -78.656894
# 6  ChIJVWqfm3xuk1QRdrgLettlTH0  43.804133 -120.554201
# 7  ChIJvcTFFo_d7IAR79XMkfgilEY  35.636876 -120.654502
# 8  ChIJB8Hkg3mehoARNDJoq9RCScI  38.424211 -123.101173
# 9  ChIJd37rCctnSogR4EfMcM4e6V0  39.280645  -80.344534

# %%
# Join the place_id and coord dataframes
region_df = pd.concat([placeid_df, coord_df], axis=1, join="inner")
    
region_df
# Out:
#                                  region                     Place_id  \
# 0                     Willamette Valley  ChIJbezwJP6hlVQRBDL4exvIWSo
# 1                   Lake Michigan Shore  ChIJbWjISvi2EIgR-XXUbfv_U1k
# 2                           Napa Valley  ChIJMU8qI_lPhIARfMUQoxvSFP4
# 3                      Alexander Valley  ChIJD2TljFMUhIARBOZe4vCoE7o
# 4                         Central Coast  ChIJnShIABvyXIYRZF3DGodjgMQ
# ..                                  ...                          ...
# 244                              Hawaii  ChIJBeB5Twbb_3sRKIbMdNKCd0s
# 245                    San Diego County  ChIJHWD_IzDr24ARKAeA6yv9DTU
# 246                  Niagara Escarpment  ChIJ12YMXUm0AogRkMoAelhilAA
# 247                    Sonoma-Napa-Lake  ChIJUWVAwmcGhYARBoANHIv70Os
# 248  Sonoma County-Santa Barbara County  ChIJj7atfV0ihIAR_qYnBSATSUk
#
#                         Place_id   Latitude   Longitude
# 0    ChIJbezwJP6hlVQRBDL4exvIWSo  44.942554 -122.933762
# 1    ChIJbWjISvi2EIgR-XXUbfv_U1k  42.220870  -86.369469
# 2    ChIJMU8qI_lPhIARfMUQoxvSFP4  38.502469 -122.265389
# 3    ChIJD2TljFMUhIARBOZe4vCoE7o  38.612965 -122.769435
# 4    ChIJnShIABvyXIYRZF3DGodjgMQ  29.444497  -98.322396
# ..                           ...        ...         ...
# 244  ChIJBeB5Twbb_3sRKIbMdNKCd0s  19.896766 -155.582782
# 245  ChIJHWD_IzDr24ARKAeA6yv9DTU  32.715730 -117.161097
# 246  ChIJ12YMXUm0AogRkMoAelhilAA  44.718052  -87.595095
# 247  ChIJUWVAwmcGhYARBoANHIv70Os  38.298327 -122.286570
# 248  ChIJj7atfV0ihIAR_qYnBSATSUk  38.577956 -122.988832
#
# [249 rows x 5 columns]

# %%
# Drop Place_id column
region_df.drop(['Place_id'], axis=1)
# Out:
#                                  region   Latitude   Longitude
# 0                     Willamette Valley  44.942554 -122.933762
# 1                   Lake Michigan Shore  42.220870  -86.369469
# 2                           Napa Valley  38.502469 -122.265389
# 3                      Alexander Valley  38.612965 -122.769435
# 4                         Central Coast  29.444497  -98.322396
# ..                                  ...        ...         ...
# 244                              Hawaii  19.896766 -155.582782
# 245                    San Diego County  32.715730 -117.161097
# 246                  Niagara Escarpment  44.718052  -87.595095
# 247                    Sonoma-Napa-Lake  38.298327 -122.286570
# 248  Sonoma County-Santa Barbara County  38.577956 -122.988832
#
# [249 rows x 3 columns]

# %%
# Create connection string
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Save the region_df DataFrame to a SQL table called wineregions
region_df.to_sql(name='wineregions', con=engine)
