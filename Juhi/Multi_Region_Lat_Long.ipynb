# %%
# Dependencies to pull API
import requests
import json
# Google developer API key
from config import gkey

# %%
# Import Dependencies for Database
from config import password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import psycopg2
import pandas as pd
import time

# %%
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
engine = create_engine(db_string)
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['wine', 'uswine', 'wineregions', 'winedata_ml']

# %%
connection = engine.connect
session = Session(engine)
engine.execute("SELECT * from uswine")

# %%
col_names_list = []

for i in range(len(inspector.get_columns('wine'))):
    col_names_list.append(inspector.get_columns('wine')[i]['name'])
    
print(col_names_list)
# Out:
# ['index', 'description', 'points', 'price', 'province', 'region', 'title', 'variety', 'winery']

# %%
location_wine_df = pd.DataFrame(columns = col_names_list)
location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
                                 'title', 'variety', 'winery'], axis = 1)
# Out:
# Empty DataFrame
# Columns: [index, region]
# Index: []

# %%
# Inner join for wines and regions
import sys
join_db = engine.execute("SELECT DISTINCT region from uswine")
for record in join_db:
    record_series = pd.Series((record), index = location_wine_df.columns)
    
    location_wine_df = location_wine_df.append(record_series, ignore_index=True, verify_integrity = True)

# %%
# Display df columns
location_wine_df
# Out:
#     index description points price province                          region  \
# 0     NaN         NaN    NaN   NaN      NaN  Paso Robles Highlands District
# 1     NaN         NaN    NaN   NaN      NaN                     Lake County
# 2     NaN         NaN    NaN   NaN      NaN                  Central Valley
# 3     NaN         NaN    NaN   NaN      NaN              Santa Clara Valley
# 4     NaN         NaN    NaN   NaN      NaN            Russian River Valley
# ..    ...         ...    ...   ...      ...                             ...
# 205   NaN         NaN    NaN   NaN      NaN                 Monterey County
# 206   NaN         NaN    NaN   NaN      NaN          San Luis Obispo County
# 207   NaN         NaN    NaN   NaN      NaN                    Marin County
# 208   NaN         NaN    NaN   NaN      NaN          Templeton Gap District
# 209   NaN         NaN    NaN   NaN      NaN                   Placer County
#
#     title variety winery
# 0     NaN     NaN    NaN
# 1     NaN     NaN    NaN
# 2     NaN     NaN    NaN
# 3     NaN     NaN    NaN
# 4     NaN     NaN    NaN
# ..    ...     ...    ...
# 205   NaN     NaN    NaN
# 206   NaN     NaN    NaN
# 207   NaN     NaN    NaN
# 208   NaN     NaN    NaN
# 209   NaN     NaN    NaN
#
# [210 rows x 9 columns]

# %%
# Drop unnecessary columns and duplicates
region_df = location_wine_df.drop(columns = ['index','description', 'points', 'price', 'province',
                                             'title', 'variety', 'winery'], axis = 1)
region_df
# Out:
#                              region
# 0    Paso Robles Highlands District
# 1                       Lake County
# 2                    Central Valley
# 3                Santa Clara Valley
# 4              Russian River Valley
# ..                              ...
# 205                 Monterey County
# 206          San Luis Obispo County
# 207                    Marin County
# 208          Templeton Gap District
# 209                   Placer County
#
# [210 rows x 1 columns]

# %%
# Create a region list
region_list = list(region_df['region'])
region_list
# Out:
# ['Paso Robles Highlands District',
#  'Lake County',
#  'Central Valley',
#  'Santa Clara Valley',
#  'Russian River Valley',
#  'Clements Hills',
#  'Temecula Valley',
#  'Sonoma County-Monterey County',
#  'California-Oregon',
#  'Napa-Mendocino-Sonoma',
#  'Anderson Valley',
#  'Solano County',
#  'Ancient Lakes',
#  'Yakima Valley',
#  'Atlas Peak',
#  'Polk County',
#  'Lime Kiln Valley',
#  'Sonoma County-Monterey County-Napa County',
#  'Columbia Valley ',
#  'North Coast',
#  'Puget Sound',
#  'Fair Play',
#  'Rutherford',
#  'Washington',
#  'Malibu-Newton Canyon',
#  'Sonoma County-Monterey County-Santa Barbara County',
#  'Sonoma Mountain',
#  'Monterey-Santa Barbara-Sonoma',
#  'Alta Mesa',
#  'Malibu Coast',
#  'Sonoma County-Napa County',
#  'Rogue Valley',
#  'Calaveras County',
#  'El Dorado',
#  'Santa Ynez Valley',
#  'Solano County Green Valley',
#  'San Luis Obispo',
#  'Temecula',
#  'Eola-Amity Hills',
#  'Mokelumne River',
#  'Santa Lucia Highlands',
#  'Napa County-Lake County',
#  'Umpqua Valley',
#  'Amador-Napa',
#  'Guenoc Valley',
#  'Mendocino Ridge',
#  'Santa Maria Valley',
#  'Yolo County',
#  'Los Carneros',
#  'Napa County',
#  'Calistoga',
#  'Oregon',
#  'Red Hills Lake County',
#  'Napa-Sonoma',
#  'Naches Heights',
#  'Central Coast',
#  'Elkton Oregon',
#  'Oak Knoll District',
#  'Coombsville',
#  'Madera',
#  'California Other',
#  'San Antonio Valley',
#  'Ventura County',
#  'Columbia Valley-Walla Walla Valley',
#  'Santa Clara County',
#  'Chehalem Mountains',
#  'Sonoma-Napa',
#  'Napa Valley',
#  'Saddle Rock-Malibu',
#  'Chalone',
#  'Napa-Amador',
#  'Mount Harlan',
#  'Cucamonga Valley',
#  'Willamette Valley',
#  'Walla Walla Valley ',
#  'Horse Heaven Hills',
#  'Lake Chelan',
#  'Monterey-San Luis Obispo-Santa Barbara',
#  'Paicines',
#  'Paso Robles Willow Creek District',
#  'Oakville',
#  'Oregon Other',
#  'Sonoma-Mendocino',
#  'Mt. Harlan',
#  'Tehama County',
#  'Redwood Valley',
#  'Shenandoah Valley ',
#  'Dundee Hills',
#  'Sonoma-Napa-Mendocino',
#  'Santa Barbara-Monterey',
#  'Happy Canyon of Santa Barbara',
#  'Suisun Valley',
#  'Santa Barbara',
#  'Adelaida District',
#  'Howell Mountain',
#  'Sonoma County-San Joaquin County',
#  'Napa County-Sonoma County-San Joaquin County',
#  'Rattlesnake Hills',
#  'Napa County-Sonoma County',
#  'California',
#  'Napa County-Sonoma County-Lake County',
#  'McDowell Valley',
#  'Green Valley',
#  'Dry Creek Valley',
#  'Fort Ross-Seaview',
#  'Contra Costa County',
#  'Moon Mountain District Sonoma County',
#  'Bennett Valley',
#  'Big Valley District-Lake County',
#  'San Francisco Bay-Livermore Valley',
#  'Nevada County',
#  'San Francisco Bay',
#  'Sonoma Valley',
#  'Lake-Sonoma-Napa',
#  'Carmel Valley',
#  'Clear Lake',
#  'Santa Cruz Mountains',
#  'Columbia Gorge ',
#  'Yamhill County',
#  'Mendocino County',
#  'Capay Valley',
#  'Ribbon Ridge',
#  'Wahluke Slope',
#  'Dunnigan Hills',
#  'Sierra Foothills',
#  'El Dorado County',
#  'Napa-Sonoma-Marin',
#  'Chiles Valley',
#  'Monterey County-Napa County',
#  'Santa Margarita Ranch',
#  'Napa-Mendocino-Sonoma-Marin',
#  'Southern Oregon',
#  'York Mountain',
#  'Mendocino-Amador',
#  'Livermore Valley',
#  'Mount Veeder',
#  'Northern Sonoma',
#  'High Valley',
#  'Snipes Mountain',
#  'Sierra Pelona Valley',
#  'Pine Mountain-Cloverdale Peak',
#  'Applegate Valley',
#  'Kelsey Bench-Lake County',
#  'River Junction',
#  'Ben Lomond Mountain',
#  'Amador County',
#  'Lake County-Sonoma County',
#  'Santa Cruz County',
#  'Carneros-Napa Valley',
#  'St. Helena',
#  'Lake County-Mendocino County',
#  'Lodi',
#  'Sonoma County',
#  'Paso Robles',
#  'Sonoma-Santa Barbara-Mendocino',
#  'San Benito County',
#  'Spring Mountain District',
#  'Ballard Canyon',
#  'Carneros',
#  'El Pomar District',
#  'Cienega Valley',
#  'Ramona Valley',
#  'Chelan County',
#  'Potter Valley',
#  'Sonoma County-Santa Barbara County',
#  'Napa',
#  'Sta. Rita Hills',
#  'Cole Ranch',
#  'Yountville',
#  'Chalk Hill',
#  'Sonoma Coast',
#  'San Bernabe',
#  'Yorkville Highlands',
#  'Mendocino-Lake',
#  'Stags Leap District',
#  'McMinnville',
#  'Clarksburg',
#  'Red Mountain',
#  'Sonoma County-Lake County',
#  'Napa-Carneros',
#  'Santa Barbara County',
#  'Columbia Valley',
#  'Alexander Valley',
#  'Arroyo Grande Valley',
#  'Edna Valley',
#  'Antelope Valley of the California High Desert',
#  'Napa-Monterey-Mendocino',
#  'Knights Valley',
#  'Tuolumne County',
#  'South Coast',
#  'Monterey',
#  'Sonoma-Napa-Lake',
#  'Monterey-Santa Barbara',
#  'Diamond Mountain District',
#  'Mendocino',
#  'Humboldt County',
#  'Sonoma',
#  'Rockpile',
#  'San Diego County',
#  'Monterey County-Napa County-Sonoma County',
#  'Sonoma-Napa-Monterey',
#  'San Lucas',
#  'Fiddletown',
#  'Mendocino-Lake County-Napa',
#  'Arroyo Seco',
#  'Monterey County',
#  'San Luis Obispo County',
#  'Marin County',
#  'Templeton Gap District',
#  'Placer County']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?inputtype=textquery&key='+ gkey

# %%
# Format regions to a string
regions = str(region_df)
regions.format
# Out:
# <function str.format>

# %%
# Create an empty list to hold the region data.
place_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the regions in the list.
for i, region in enumerate(region_list):

 # Group regions in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    placeid_url = valley_url + '&input='+ region
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the region.
    print(f"Processing Record {record_count} of Set {set_count} | {region}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for each of the regions.
    try:
        # Parse the JSON and retrieve data.
        region_url = requests.get(placeid_url).json()
        # Parse out the needed data.
        place_id = region_url['candidates'][0]['place_id']
        # Append the region information into place_id_data list.
        place_id_data.append({"region": region, 
                              "Place_id": place_id})

# If an error is experienced, skip the region.
    except:
        print("region not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | Paso Robles Highlands District
# Processing Record 2 of Set 1 | Lake County
# Processing Record 3 of Set 1 | Central Valley
# Processing Record 4 of Set 1 | Santa Clara Valley
# Processing Record 5 of Set 1 | Russian River Valley
# Processing Record 6 of Set 1 | Clements Hills
# Processing Record 7 of Set 1 | Temecula Valley
# Processing Record 8 of Set 1 | Sonoma County-Monterey County
# region not found. Skipping...
# Processing Record 9 of Set 1 | California-Oregon
# Processing Record 10 of Set 1 | Napa-Mendocino-Sonoma
# Processing Record 11 of Set 1 | Anderson Valley
# Processing Record 12 of Set 1 | Solano County
# Processing Record 13 of Set 1 | Ancient Lakes
# Processing Record 14 of Set 1 | Yakima Valley
# Processing Record 15 of Set 1 | Atlas Peak
# Processing Record 16 of Set 1 | Polk County
# Processing Record 17 of Set 1 | Lime Kiln Valley
# Processing Record 18 of Set 1 | Sonoma County-Monterey County-Napa County
# Processing Record 19 of Set 1 | Columbia Valley
# Processing Record 20 of Set 1 | North Coast
# Processing Record 21 of Set 1 | Puget Sound
# Processing Record 22 of Set 1 | Fair Play
# Processing Record 23 of Set 1 | Rutherford
# Processing Record 24 of Set 1 | Washington
# Processing Record 25 of Set 1 | Malibu-Newton Canyon
# Processing Record 26 of Set 1 | Sonoma County-Monterey County-Santa Barbara County
# Processing Record 27 of Set 1 | Sonoma Mountain
# Processing Record 28 of Set 1 | Monterey-Santa Barbara-Sonoma
# Processing Record 29 of Set 1 | Alta Mesa
# Processing Record 30 of Set 1 | Malibu Coast
# Processing Record 31 of Set 1 | Sonoma County-Napa County
# region not found. Skipping...
# Processing Record 32 of Set 1 | Rogue Valley
# Processing Record 33 of Set 1 | Calaveras County
# Processing Record 34 of Set 1 | El Dorado
# Processing Record 35 of Set 1 | Santa Ynez Valley
# Processing Record 36 of Set 1 | Solano County Green Valley
# Processing Record 37 of Set 1 | San Luis Obispo
# Processing Record 38 of Set 1 | Temecula
# Processing Record 39 of Set 1 | Eola-Amity Hills
# Processing Record 40 of Set 1 | Mokelumne River
# Processing Record 41 of Set 1 | Santa Lucia Highlands
# Processing Record 42 of Set 1 | Napa County-Lake County
# Processing Record 43 of Set 1 | Umpqua Valley
# Processing Record 44 of Set 1 | Amador-Napa
# Processing Record 45 of Set 1 | Guenoc Valley
# Processing Record 46 of Set 1 | Mendocino Ridge
# Processing Record 47 of Set 1 | Santa Maria Valley
# Processing Record 48 of Set 1 | Yolo County
# Processing Record 49 of Set 1 | Los Carneros
# Processing Record 50 of Set 1 | Napa County
# Processing Record 1 of Set 2 | Calistoga
# Processing Record 2 of Set 2 | Oregon
# Processing Record 3 of Set 2 | Red Hills Lake County
# Processing Record 4 of Set 2 | Napa-Sonoma
# region not found. Skipping...
# Processing Record 5 of Set 2 | Naches Heights
# Processing Record 6 of Set 2 | Central Coast
# Processing Record 7 of Set 2 | Elkton Oregon
# Processing Record 8 of Set 2 | Oak Knoll District
# Processing Record 9 of Set 2 | Coombsville
# Processing Record 10 of Set 2 | Madera
# Processing Record 11 of Set 2 | California Other
# Processing Record 12 of Set 2 | San Antonio Valley
# Processing Record 13 of Set 2 | Ventura County
# Processing Record 14 of Set 2 | Columbia Valley-Walla Walla Valley
# Processing Record 15 of Set 2 | Santa Clara County
# Processing Record 16 of Set 2 | Chehalem Mountains
# Processing Record 17 of Set 2 | Sonoma-Napa
# Processing Record 18 of Set 2 | Napa Valley
# Processing Record 19 of Set 2 | Saddle Rock-Malibu
# Processing Record 20 of Set 2 | Chalone
# Processing Record 21 of Set 2 | Napa-Amador
# Processing Record 22 of Set 2 | Mount Harlan
# Processing Record 23 of Set 2 | Cucamonga Valley
# Processing Record 24 of Set 2 | Willamette Valley
# Processing Record 25 of Set 2 | Walla Walla Valley
# Processing Record 26 of Set 2 | Horse Heaven Hills
# Processing Record 27 of Set 2 | Lake Chelan
# Processing Record 28 of Set 2 | Monterey-San Luis Obispo-Santa Barbara
# Processing Record 29 of Set 2 | Paicines
# Processing Record 30 of Set 2 | Paso Robles Willow Creek District
# Processing Record 31 of Set 2 | Oakville
# Processing Record 32 of Set 2 | Oregon Other
# Processing Record 33 of Set 2 | Sonoma-Mendocino
# region not found. Skipping...
# Processing Record 34 of Set 2 | Mt. Harlan
# Processing Record 35 of Set 2 | Tehama County
# Processing Record 36 of Set 2 | Redwood Valley
# Processing Record 37 of Set 2 | Shenandoah Valley
# Processing Record 38 of Set 2 | Dundee Hills
# Processing Record 39 of Set 2 | Sonoma-Napa-Mendocino
# Processing Record 40 of Set 2 | Santa Barbara-Monterey
# region not found. Skipping...
# Processing Record 41 of Set 2 | Happy Canyon of Santa Barbara
# Processing Record 42 of Set 2 | Suisun Valley
# Processing Record 43 of Set 2 | Santa Barbara
# Processing Record 44 of Set 2 | Adelaida District
# Processing Record 45 of Set 2 | Howell Mountain
# Processing Record 46 of Set 2 | Sonoma County-San Joaquin County
# region not found. Skipping...
# Processing Record 47 of Set 2 | Napa County-Sonoma County-San Joaquin County
# Processing Record 48 of Set 2 | Rattlesnake Hills
# Processing Record 49 of Set 2 | Napa County-Sonoma County
# Processing Record 50 of Set 2 | California
# Processing Record 1 of Set 3 | Napa County-Sonoma County-Lake County
# region not found. Skipping...
# Processing Record 2 of Set 3 | McDowell Valley
# region not found. Skipping...
# Processing Record 3 of Set 3 | Green Valley
# Processing Record 4 of Set 3 | Dry Creek Valley
# Processing Record 5 of Set 3 | Fort Ross-Seaview
# Processing Record 6 of Set 3 | Contra Costa County
# Processing Record 7 of Set 3 | Moon Mountain District Sonoma County
# Processing Record 8 of Set 3 | Bennett Valley
# Processing Record 9 of Set 3 | Big Valley District-Lake County
# region not found. Skipping...
# Processing Record 10 of Set 3 | San Francisco Bay-Livermore Valley
# Processing Record 11 of Set 3 | Nevada County
# Processing Record 12 of Set 3 | San Francisco Bay
# Processing Record 13 of Set 3 | Sonoma Valley
# Processing Record 14 of Set 3 | Lake-Sonoma-Napa
# Processing Record 15 of Set 3 | Carmel Valley
# Processing Record 16 of Set 3 | Clear Lake
# Processing Record 17 of Set 3 | Santa Cruz Mountains
# Processing Record 18 of Set 3 | Columbia Gorge
# Processing Record 19 of Set 3 | Yamhill County
# Processing Record 20 of Set 3 | Mendocino County
# Processing Record 21 of Set 3 | Capay Valley
# Processing Record 22 of Set 3 | Ribbon Ridge
# Processing Record 23 of Set 3 | Wahluke Slope
# Processing Record 24 of Set 3 | Dunnigan Hills
# Processing Record 25 of Set 3 | Sierra Foothills
# Processing Record 26 of Set 3 | El Dorado County
# Processing Record 27 of Set 3 | Napa-Sonoma-Marin
# region not found. Skipping...
# Processing Record 28 of Set 3 | Chiles Valley
# Processing Record 29 of Set 3 | Monterey County-Napa County
# region not found. Skipping...
# Processing Record 30 of Set 3 | Santa Margarita Ranch
# Processing Record 31 of Set 3 | Napa-Mendocino-Sonoma-Marin
# Processing Record 32 of Set 3 | Southern Oregon
# Processing Record 33 of Set 3 | York Mountain
# Processing Record 34 of Set 3 | Mendocino-Amador
# region not found. Skipping...
# Processing Record 35 of Set 3 | Livermore Valley
# Processing Record 36 of Set 3 | Mount Veeder
# Processing Record 37 of Set 3 | Northern Sonoma
# Processing Record 38 of Set 3 | High Valley
# Processing Record 39 of Set 3 | Snipes Mountain
# Processing Record 40 of Set 3 | Sierra Pelona Valley
# Processing Record 41 of Set 3 | Pine Mountain-Cloverdale Peak
# Processing Record 42 of Set 3 | Applegate Valley
# Processing Record 43 of Set 3 | Kelsey Bench-Lake County
# region not found. Skipping...
# Processing Record 44 of Set 3 | River Junction
# Processing Record 45 of Set 3 | Ben Lomond Mountain
# Processing Record 46 of Set 3 | Amador County
# Processing Record 47 of Set 3 | Lake County-Sonoma County
# Processing Record 48 of Set 3 | Santa Cruz County
# Processing Record 49 of Set 3 | Carneros-Napa Valley
# Processing Record 50 of Set 3 | St. Helena
# Processing Record 1 of Set 4 | Lake County-Mendocino County
# Processing Record 2 of Set 4 | Lodi
# Processing Record 3 of Set 4 | Sonoma County
# Processing Record 4 of Set 4 | Paso Robles
# Processing Record 5 of Set 4 | Sonoma-Santa Barbara-Mendocino
# Processing Record 6 of Set 4 | San Benito County
# Processing Record 7 of Set 4 | Spring Mountain District
# Processing Record 8 of Set 4 | Ballard Canyon
# Processing Record 9 of Set 4 | Carneros
# Processing Record 10 of Set 4 | El Pomar District
# Processing Record 11 of Set 4 | Cienega Valley
# Processing Record 12 of Set 4 | Ramona Valley
# region not found. Skipping...
# Processing Record 13 of Set 4 | Chelan County
# Processing Record 14 of Set 4 | Potter Valley
# Processing Record 15 of Set 4 | Sonoma County-Santa Barbara County
# Processing Record 16 of Set 4 | Napa
# Processing Record 17 of Set 4 | Sta. Rita Hills
# Processing Record 18 of Set 4 | Cole Ranch
# Processing Record 19 of Set 4 | Yountville
# Processing Record 20 of Set 4 | Chalk Hill
# Processing Record 21 of Set 4 | Sonoma Coast
# Processing Record 22 of Set 4 | San Bernabe
# Processing Record 23 of Set 4 | Yorkville Highlands
# Processing Record 24 of Set 4 | Mendocino-Lake
# Processing Record 25 of Set 4 | Stags Leap District
# Processing Record 26 of Set 4 | McMinnville
# Processing Record 27 of Set 4 | Clarksburg
# Processing Record 28 of Set 4 | Red Mountain
# region not found. Skipping...
# Processing Record 29 of Set 4 | Sonoma County-Lake County
# Processing Record 30 of Set 4 | Napa-Carneros
# Processing Record 31 of Set 4 | Santa Barbara County
# Processing Record 32 of Set 4 | Columbia Valley
# Processing Record 33 of Set 4 | Alexander Valley
# Processing Record 34 of Set 4 | Arroyo Grande Valley
# Processing Record 35 of Set 4 | Edna Valley
# Processing Record 36 of Set 4 | Antelope Valley of the California High Desert
# Processing Record 37 of Set 4 | Napa-Monterey-Mendocino
# Processing Record 38 of Set 4 | Knights Valley
# Processing Record 39 of Set 4 | Tuolumne County
# Processing Record 40 of Set 4 | South Coast
# Processing Record 41 of Set 4 | Monterey
# Processing Record 42 of Set 4 | Sonoma-Napa-Lake
# Processing Record 43 of Set 4 | Monterey-Santa Barbara
# region not found. Skipping...
# Processing Record 44 of Set 4 | Diamond Mountain District
# Processing Record 45 of Set 4 | Mendocino
# Processing Record 46 of Set 4 | Humboldt County
# Processing Record 47 of Set 4 | Sonoma
# Processing Record 48 of Set 4 | Rockpile
# Processing Record 49 of Set 4 | San Diego County
# Processing Record 50 of Set 4 | Monterey County-Napa County-Sonoma County
# Processing Record 1 of Set 5 | Sonoma-Napa-Monterey
# Processing Record 2 of Set 5 | San Lucas
# Processing Record 3 of Set 5 | Fiddletown
# Processing Record 4 of Set 5 | Mendocino-Lake County-Napa
# Processing Record 5 of Set 5 | Arroyo Seco
# Processing Record 6 of Set 5 | Monterey County
# Processing Record 7 of Set 5 | San Luis Obispo County
# Processing Record 8 of Set 5 | Marin County
# Processing Record 9 of Set 5 | Templeton Gap District
# Processing Record 10 of Set 5 | Placer County
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create place_id dataframe
placeid_df = pd.DataFrame(place_id_data)
placeid_df.head(10)
# Out:
#                            region                     Place_id
# 0  Paso Robles Highlands District  ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# 1                     Lake County  ChIJKdUvmscAD4gRZsVGNFFqkhs
# 2                  Central Valley  ChIJyZkVOx6DgoARU5w0SCOkBvY
# 3              Santa Clara Valley  ChIJ4Zu4Go4xjoARNcsmHfjo_dI
# 4            Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 5                  Clements Hills  ChIJLyGI6pDQdUgRApb5vVVHUw4
# 6                 Temecula Valley  ChIJfYKgDA5_24ARmJsb0bYUFmw
# 7               California-Oregon  ChIJjUnLoHnJnIARkjPe0zv-PkA
# 8           Napa-Mendocino-Sonoma  ChIJ3_Uwla-uhYARAAmNhPiOav0
# 9                 Anderson Valley  ChIJa8v27oYSgYARRA6kQu3ru5s

# %%
# Create place_id list
place_id_list = list(placeid_df['Place_id'])
place_id_list
# Out:
# ['ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJKdUvmscAD4gRZsVGNFFqkhs',
#  'ChIJyZkVOx6DgoARU5w0SCOkBvY',
#  'ChIJ4Zu4Go4xjoARNcsmHfjo_dI',
#  'ChIJhddrQaV7gYAR0SLRbKP8lNc',
#  'ChIJLyGI6pDQdUgRApb5vVVHUw4',
#  'ChIJfYKgDA5_24ARmJsb0bYUFmw',
#  'ChIJjUnLoHnJnIARkjPe0zv-PkA',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJa8v27oYSgYARRA6kQu3ru5s',
#  'ChIJB_R9n88XhYAR-L8fjKYikj0',
#  'ChIJUVu5cvx4mVQRb1CuMS_kcro',
#  'ChIJtwIWxMKHl1QR30xHsvUB3dI',
#  'ChIJW_s0SRvHQIYREXn0DXARk9U',
#  'ChIJ0bDiw-jyOIYRPrqcrZnzyQc',
#  'ChIJL4EPzdHbt4kRyUilrlIwE00',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJ98VFkPPAQIYR75ugr82kemY',
#  'ChIJqfWOgUHBQIYRZxQ6ObUFWuo',
#  'ChIJ4TiXsFQ-kFQRAX7WBEamkDM',
#  'ChIJVxVoJMmIWIgROSgV3SYKqi8',
#  'ChIJkUqt1aP4wokRAB032V1oBsw',
#  'ChIJ-bDD5__lhVQRuvNfbGh4QpQ',
#  'ChIJPe2rmfci6IARPNp63LhdpgQ',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJoenF7NCyhYARakPvDUbpQQE',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJ8WejwhXZQIYRwKRHGSX22W0',
#  'ChIJP9YI-akd6IARWozqsnEtt5M',
#  'ChIJg3cxDPaHxVQRde0DiGnDILs',
#  'ChIJgQMawEWokIARUF3VYX30ANw',
#  'ChIJ0YtmY124QIYRv7mt9O5tZXM',
#  'ChIJH3v79pZT6YAR-MXTvZmd134',
#  'ChIJHWTSAsMRhYAR7nqXk1q6deI',
#  'ChIJJ8Jse77m7IARRg_vzsKQArw',
#  'ChIJI74a9VJi24ARqAY4oIgOvGg',
#  'ChIJU2oMa7zAQIYRkEg9eGVDXnE',
#  'ChIJ_fI5LWWsmoARS-gGEa8EBG0',
#  'ChIJY2jxLkBukoARNMBojauvJF8',
#  'ChIJWYxlsL7whIARfR_OUuFQLHQ',
#  'ChIJsUP3Td8ixFQRyE51ASKNrd0',
#  'ChIJ0ex0eCLBQIYRUt2Q8lj_o98',
#  'ChIJiXWJGHVmhIARgRDJUsHC0z8',
#  'ChIJ67ZzfzRNgIARZVnxHr6t1E8',
#  'ChIJS5qabCO_QIYRBxiySMKtPkc',
#  'ChIJ69wnuncnhYAR4jxmM3iXoXE',
#  'ChIJNRmgFHlA6YAR9LRoUsOcDTs',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJkTJxhwlDhIARQO6YM2Hiiwc',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJhWWt7fv7OYYR72JNjKHpWVE',
#  'ChIJyUnptFdil1QRG49Wjiuz6eY',
#  'ChIJn1wzOELdQIYRJsEGV66URVc',
#  'ChIJk6HV2GtUwVQR5Irl6J4W7QI',
#  'ChIJG27TPB2xQIYRWvuLxzyDuG8',
#  'ChIJrQB7dGgGhYARh1UG9UP-YFs',
#  'ChIJA9vG_ZILlIAREGnnItpCwzY',
#  'ChIJicrszzm_QIYRs1vXNrPlnQA',
#  'ChIJP-s5hlDSkYARr2Hy9ng7dKk',
#  'ChIJqXcAstJi6YARs7DDR_CQld0',
#  'ChIJo7Y_15XEQIYRn-LjD1tyRBc',
#  'ChIJd_Y0eVIvkIARuQyDN0F1LBA',
#  'ChIJZznzuJsVlVQRY3ZPAz77fTk',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJvcCvpxEj6IARX8hjBiy24HQ',
#  'ChIJU2-BGylokoARijhqgUPyedw',
#  'ChIJ0ex0eCLBQIYRUt2Q8lj_o98',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJxe6eYrE0w4AR8OIYbSkxP_8',
#  'ChIJbezwJP6hlVQRBDL4exvIWSo',
#  'ChIJBwOnamNqolQRlUFeGjkeZrc',
#  'ChIJJSIr8a0cmFQRZIWx0ZnZtlo',
#  'ChIJiewjJFxum1QR4B1v94YWsBI',
#  'ChIJR2mFLVvljYARhYhkKw1Zbr0',
#  'ChIJYdTTrR0YkoARQcfiJ6VNmXc',
#  'ChIJGeXB-Bfa7IARVfiQUCn-s6Y',
#  'ChIJeZlyj4tbK4gR0Bsjxyh7AwU',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJ6_8ezximgoARGaPfZ5WDxqo',
#  'ChIJK-4fNG55gYARh9uaMCHzpOA',
#  'ChIJNcZLgG_ttIkRaSyg4lb5xm4',
#  'ChIJkczwbduTQIYR9w8u8QGUb-U',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJCcThuvUT6YARzc7brv6SLmY',
#  'ChIJwWWZ5GwRhYARtCTlQhqqAeg',
#  'ChIJ1YMtb8cU6YARSHa612Q60cg',
#  'ChIJo-5SWSjR7IARXp9cdqmlAeo',
#  'ChIJo4LFduhbhIARTBAsD475eGc',
#  'ChIJ31ZZ5gY-kIAR0dtYpsEqJEc',
#  'ChIJR-sBm-zXmVQRNUJpzhRYx7Q',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#  'ChIJ93t8eGu-QIYRnnp1qFWGux4',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJqScrY5WkhoARlNUv2wg3tsA',
#  'ChIJ3QQ6ifNuhYAR4fM4Ln-yyVk',
#  'ChIJH1iqDT2phYAROLQAfJJ_0J8',
#  'ChIJKzh9MGNIhIARECiBFxnNZt8',
#  'ChIJDz9-FlXnj4ARrGzeU4wZ3Ao',
#  'ChIJX_aX8TOFm4ARgtETUAvolo8',
#  'ChIJBwohpl6bj4AREMlJ8U8PlaI',
#  'ChIJI-UCgdlShIARPnjSSZd4foM',
#  'ChIJbbN3nxlbhIARBx_wpkOFTuQ',
#  'ChIJvUku7X3zjYARtkSqSWQJ2qA',
#  'ChIJ1azLGlmcQIYR4bjfKRexK6s',
#  'ChIJV7FWSmU7joARrCMjR_-QG_4',
#  'ChIJzfeI19gYllQRAdd-nffBy-E',
#  'ChIJ38wjXU1KlVQRnXojmjNOBBE',
#  'ChIJh-hRvjCOgYARFQFu8mmzZyM',
#  'ChIJP5PWeHDphIARy2FLJhKIJjc',
#  'ChIJqbp20mvHQIYRU_w6C7ixDfE',
#  'ChIJV96zdT2umVQRoqO1RPkJ1JU',
#  'ChIJ-xA8jVDAhIARYOH-hhbSx24',
#  'ChIJ26Z6dJzqQIYRGkZw82ndznI',
#  'ChIJhQd-sopHmoARt9CBUcuaJB4',
#  'ChIJOamgpUT4hIARKVKqNBzJQXM',
#  'ChIJO7OVyhzx7IARKtcI0P4tfVc',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJffBbhegNxlQRyq1bp4KiPOY',
#  'ChIJBbbsO__AQIYRxQ5bIAzK6Nw',
#  'ChIJyTz6fqDnj4ARImnwYa7AE3E',
#  'ChIJE2iH7ldThIARzLXbwsD5C8w',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJfbvz-lq_QIYRphYNuHhPDvE',
#  'ChIJ3WW0OJ0jmFQRmvZ-oWS-6iQ',
#  'ChIJmUlcX5OKwoARog_bRXgdajw',
#  'ChIJB9lyfRj5g4ARblOcfrmkRrg',
#  'ChIJjV18y1V9xVQRNey4WKdjfrs',
#  'ChIJJ7yD3bsGWYYRHPK4D6-f3Cc',
#  'ChIJwZQP0GRzU4cRaiTTgfLlAHk',
#  'ChIJo-0fEllAmoAReviEN7sDX08',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJfzsx1n8TjoARGbNHDCbAPhU',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJ4-UsNRPi6gQRpp8ZUARPgK4',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJNTjFJtmhmoARRuhsu5jkrY4',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJvcTFFo_d7IAR79XMkfgilEY',
#  'ChIJDYp1OaiuhYARIwCuBhIwVOs',
#  'ChIJ_8VcLuc7koARQXmgrXGnQxc',
#  'ChIJBQe7GKjKQIYRxG0mtKNvREs',
#  'ChIJ15UlxTFV6YAR7rCBTktGyM0',
#  'ChIJc91fIoDbRIYR_iZWpJpCMiE',
#  'ChIJrZOHqndEE4cR4G9TwVWzjaY',
#  'ChIJ9_fr2eEZkoARE_rvkQgeKQg',
#  'ChIJVZv5TUp_m1QRmJDpy3364Ys',
#  'ChIJE73iaKRwgYARCU5su-oXmZc',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJlUVtthq-QIYROvuI8dr98Mg',
#  'ChIJt82dTpwe7IAR9oK1FQs83rg',
#  'ChIJA_obkPM1R4YRkWSOF6_6hCg',
#  'ChIJfRoJQE1VhIARTB6YA4IIzN0',
#  'ChIJTeRJv4G_QIYR-AWswId7qlA',
#  'ChIJB8Hkg3mehoARNDJoq9RCScI',
#  'ChIJ3SmLUNGWYoYRGDGqnmIwOPo',
#  'ChIJ7ZPooopagYAR9n4U4o9Jyqk',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJU2oMa7zAQIYRkEg9eGVDXnE',
#  'ChIJo3PJF7dOlVQRSM9F2xtwRMo',
#  'ChIJd37rCctnSogR4EfMcM4e6V0',
#  'ChIJ3Qfw6jZVgYAR6v6_SxmR4cc',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJXxfrQWYM7IAR_9ACRVau1Wo',
#  'ChIJ98VFkPPAQIYR75ugr82kemY',
#  'ChIJD2TljFMUhIARBOZe4vCoE7o',
#  'ChIJcXsYoF6_QIYRHQobq-W9W_8',
#  'ChIJ00tXuZzAQIYRIR-pBinC7rE',
#  'ChIJA3cgzNJDwoARX6xdvBafiAU',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJQ7KICATAQIYRUa_rbUSNH6w',
#  'ChIJUXsaVaYxl4ARpyB7IpcuWGU',
#  'ChIJHVog23DAQIYRVJAgYseR18I',
#  'ChIJkfu1cFLkjYARXj1K2AlJSO4',
#  'ChIJUWVAwmcGhYARBoANHIv70Os',
#  'ChIJ2blEOUO7nYARLzTrfw18ILU',
#  'ChIJM-tWPGuygYARO7PAQfKXD9Y',
#  'ChIJsVTwdfTf01QRfyaxfTR5OjQ',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJY8sovOHQQIYRQLB2Z9eO6SU',
#  'ChIJHWD_IzDr24ARKAeA6yv9DTU',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJoQjlifNKr4YRaLiiwWLfpEs',
#  'ChIJr2rpnolmmoARXFxc3qp4ks4',
#  'ChIJi9P3VTRNgIARweg4ogTKFdI',
#  'ChIJJ_XlIbhokoARgX6K5CGyl5Y',
#  'ChIJUV7XWK6z7IARFNInOyD3gBc',
#  'ChIJX3PwOP2E7IAR9ToVLk_oEGY',
#  'ChIJ82aOMnyhhYARHLRVUdyH0As',
#  'ChIJMdXLkFlFE4cRHXwvGjutgIc',
#  'ChIJk-ZOZm4Sm4AR8eQ1nDcJNKA']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url2 = ('https://maps.googleapis.com/maps/api/place/details/json?&key='+ gkey)

# %%
# Create an empty list to hold the coord data.
coord_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the place ids in the list.
for i, placeids in enumerate(place_id_list):

 # Group place ids in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    coord_url = valley_url2 + '&place_id='+ placeids
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the place ids.
    print(f"Processing Record {record_count} of Set {set_count} | {placeids}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for the place ids and retrieve the lat long info.
    try:
        # Parse the JSON and retrieve data.
        geo_url = requests.get(coord_url).json()
        # Parse out the needed data.
        lat_id = geo_url['result']['geometry']['location']['lat']
        long_id = geo_url['result']['geometry']['location']['lng']
        # Append the region information into place_id_data list.
        coord_id_data.append({"Place_id": placeids, 
                              "Latitude": lat_id,
                             "Longitude": long_id})
        


# If an error is experienced, skip the record.
    except:
        print("record not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# Processing Record 2 of Set 1 | ChIJKdUvmscAD4gRZsVGNFFqkhs
# Processing Record 3 of Set 1 | ChIJyZkVOx6DgoARU5w0SCOkBvY
# Processing Record 4 of Set 1 | ChIJ4Zu4Go4xjoARNcsmHfjo_dI
# Processing Record 5 of Set 1 | ChIJhddrQaV7gYAR0SLRbKP8lNc
# Processing Record 6 of Set 1 | ChIJLyGI6pDQdUgRApb5vVVHUw4
# Processing Record 7 of Set 1 | ChIJfYKgDA5_24ARmJsb0bYUFmw
# Processing Record 8 of Set 1 | ChIJjUnLoHnJnIARkjPe0zv-PkA
# Processing Record 9 of Set 1 | ChIJ3_Uwla-uhYARAAmNhPiOav0
# Processing Record 10 of Set 1 | ChIJa8v27oYSgYARRA6kQu3ru5s
# Processing Record 11 of Set 1 | ChIJB_R9n88XhYAR-L8fjKYikj0
# Processing Record 12 of Set 1 | ChIJUVu5cvx4mVQRb1CuMS_kcro
# Processing Record 13 of Set 1 | ChIJtwIWxMKHl1QR30xHsvUB3dI
# Processing Record 14 of Set 1 | ChIJW_s0SRvHQIYREXn0DXARk9U
# Processing Record 15 of Set 1 | ChIJ0bDiw-jyOIYRPrqcrZnzyQc
# Processing Record 16 of Set 1 | ChIJL4EPzdHbt4kRyUilrlIwE00
# Processing Record 17 of Set 1 | ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# Processing Record 18 of Set 1 | ChIJ98VFkPPAQIYR75ugr82kemY
# Processing Record 19 of Set 1 | ChIJqfWOgUHBQIYRZxQ6ObUFWuo
# Processing Record 20 of Set 1 | ChIJ4TiXsFQ-kFQRAX7WBEamkDM
# Processing Record 21 of Set 1 | ChIJVxVoJMmIWIgROSgV3SYKqi8
# Processing Record 22 of Set 1 | ChIJkUqt1aP4wokRAB032V1oBsw
# Processing Record 23 of Set 1 | ChIJ-bDD5__lhVQRuvNfbGh4QpQ
# Processing Record 24 of Set 1 | ChIJPe2rmfci6IARPNp63LhdpgQ
# Processing Record 25 of Set 1 | ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# 8  ChIJ3_Uwla-uhYARAAmNhPiOav0  38.284000 -122.456753
# 9  ChIJa8v27oYSgYARRA6kQu3ru5s  39.086566 -123.479454

# %%
# Join the place_id and coord dataframes
region_df = pd.concat([placeid_df, coord_df], axis=1, join="inner")
    
region_df
# Out:
#                              region                     Place_id  \
# 0    Paso Robles Highlands District  ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# 1                       Lake County  ChIJKdUvmscAD4gRZsVGNFFqkhs
# 2                    Central Valley  ChIJyZkVOx6DgoARU5w0SCOkBvY
# 3                Santa Clara Valley  ChIJ4Zu4Go4xjoARNcsmHfjo_dI
# 4              Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# ..                              ...                          ...
# 189                 Monterey County  ChIJUV7XWK6z7IARFNInOyD3gBc
# 190          San Luis Obispo County  ChIJX3PwOP2E7IAR9ToVLk_oEGY
# 191                    Marin County  ChIJ82aOMnyhhYARHLRVUdyH0As
# 192          Templeton Gap District  ChIJMdXLkFlFE4cRHXwvGjutgIc
# 193                   Placer County  ChIJk-ZOZm4Sm4AR8eQ1nDcJNKA
#
#                         Place_id   Latitude   Longitude
# 0    ChIJ1xNSFmTBQIYRBDAiMLUJ-nI  29.738575  -95.471458
# 1    ChIJKdUvmscAD4gRZsVGNFFqkhs  42.368936  -87.827153
# 2    ChIJyZkVOx6DgoARU5w0SCOkBvY  40.199878 -122.201108
# 3    ChIJ4Zu4Go4xjoARNcsmHfjo_dI  37.248848 -121.839959
# 4    ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# ..                           ...        ...         ...
# 189  ChIJUV7XWK6z7IARFNInOyD3gBc  36.313620 -121.354163
# 190  ChIJX3PwOP2E7IAR9ToVLk_oEGY  35.310230 -120.435763
# 191  ChIJ82aOMnyhhYARHLRVUdyH0As  38.083403 -122.763304
# 192  ChIJMdXLkFlFE4cRHXwvGjutgIc  38.863304 -104.831604
# 193  ChIJk-ZOZm4Sm4AR8eQ1nDcJNKA  39.091575 -120.803947
#
# [194 rows x 5 columns]

# %%
# Drop Place_id column
region_df = region_df.drop(['Place_id'], axis=1)
region_df
# Out:
#                              region   Latitude   Longitude
# 0    Paso Robles Highlands District  29.738575  -95.471458
# 1                       Lake County  42.368936  -87.827153
# 2                    Central Valley  40.199878 -122.201108
# 3                Santa Clara Valley  37.248848 -121.839959
# 4              Russian River Valley  38.911980 -123.053708
# ..                              ...        ...         ...
# 189                 Monterey County  36.313620 -121.354163
# 190          San Luis Obispo County  35.310230 -120.435763
# 191                    Marin County  38.083403 -122.763304
# 192          Templeton Gap District  38.863304 -104.831604
# 193                   Placer County  39.091575 -120.803947
#
# [194 rows x 3 columns]

# %%
# Create connection string
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Save the region_df DataFrame to a SQL table called wineregions
region_df.to_sql(name='wineregions', con=engine)

# %%
region_df.to_csv("Data/region_df.csv", index=False)
