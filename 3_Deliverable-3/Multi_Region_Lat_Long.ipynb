# %%
# Dependencies to pull API
import requests
import json
# Google developer API key
from config import gkey

# %%
# Import Dependencies for Database
from config import password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import psycopg2
import pandas as pd
import time

# %%
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5434/WineEnthusiast"

# %%
engine = create_engine(db_string)
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['wine', 'us_wine', 'wine_us', 'wineregions', 'winedata_ml', 'uswine_db']

# %%
connection = engine.connect
session = Session(engine)
engine.execute("SELECT * from wine_us")

# %%
col_names_list = []

for i in range(len(inspector.get_columns('wine_us'))):
    col_names_list.append(inspector.get_columns('wine_us')[i]['name'])
    
print(col_names_list)
# Out:
# ['index', 'points', 'price', 'province', 'region_1', 'winery', 'variety', 'title', 'description', 'type']

# %%
location_wine_df = pd.DataFrame(columns = col_names_list)
location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
                                 'title', 'variety', 'winery', 'type'], axis = 1)
# Out:
# Empty DataFrame
# Columns: [index, region_1]
# Index: []

# %%
# Inner join for wines and regions
import sys
join_db = engine.execute("SELECT DISTINCT region_1 from wine_us")
for record in join_db:
    record_series = pd.Series((record), index = location_wine_df.columns)
    
    location_wine_df = location_wine_df.append(record_series, ignore_index=True, verify_integrity = True)

# %%
# Display df columns
location_wine_df
# Out:
#    index points price province               region_1 winery variety title  \
# 0    NaN    NaN   NaN      NaN   Russian River Valley    NaN     NaN   NaN
# 1    NaN    NaN   NaN      NaN        Anderson Valley    NaN     NaN   NaN
# 2    NaN    NaN   NaN      NaN        Sta. Rita Hills    NaN     NaN   NaN
# 3    NaN    NaN   NaN      NaN   Santa Cruz Mountains    NaN     NaN   NaN
# 4    NaN    NaN   NaN      NaN     Chehalem Mountains    NaN     NaN   NaN
# 5    NaN    NaN   NaN      NaN           Sonoma Coast    NaN     NaN   NaN
# 6    NaN    NaN   NaN      NaN       Mendocino County    NaN     NaN   NaN
# 7    NaN    NaN   NaN      NaN            Napa Valley    NaN     NaN   NaN
# 8    NaN    NaN   NaN      NaN          Wahluke Slope    NaN     NaN   NaN
# 9    NaN    NaN   NaN      NaN       Sierra Foothills    NaN     NaN   NaN
# 10   NaN    NaN   NaN      NaN          Yakima Valley    NaN     NaN   NaN
# 11   NaN    NaN   NaN      NaN           Red Mountain    NaN     NaN   NaN
# 12   NaN    NaN   NaN      NaN      Willamette Valley    NaN     NaN   NaN
# 13   NaN    NaN   NaN      NaN   Santa Barbara County    NaN     NaN   NaN
# 14   NaN    NaN   NaN      NaN    Walla Walla Valley     NaN     NaN   NaN
# 15   NaN    NaN   NaN      NaN     Horse Heaven Hills    NaN     NaN   NaN
# 16   NaN    NaN   NaN      NaN       Alexander Valley    NaN     NaN   NaN
# 17   NaN    NaN   NaN      NaN            Edna Valley    NaN     NaN   NaN
# 18   NaN    NaN   NaN      NaN       Livermore Valley    NaN     NaN   NaN
# 19   NaN    NaN   NaN      NaN       Columbia Valley     NaN     NaN   NaN
# 20   NaN    NaN   NaN      NaN            North Coast    NaN     NaN   NaN
# 21   NaN    NaN   NaN      NaN             Rutherford    NaN     NaN   NaN
# 22   NaN    NaN   NaN      NaN               Monterey    NaN     NaN   NaN
# 23   NaN    NaN   NaN      NaN             Washington    NaN     NaN   NaN
# 24   NaN    NaN   NaN      NaN              Mendocino    NaN     NaN   NaN
# 25   NaN    NaN   NaN      NaN           Dundee Hills    NaN     NaN   NaN
# 26   NaN    NaN   NaN      NaN           Rogue Valley    NaN     NaN   NaN
# 27   NaN    NaN   NaN      NaN      Santa Ynez Valley    NaN     NaN   NaN
# 28   NaN    NaN   NaN      NaN  Santa Lucia Highlands    NaN     NaN   NaN
# 29   NaN    NaN   NaN      NaN     Santa Maria Valley    NaN     NaN   NaN
# 30   NaN    NaN   NaN      NaN             California    NaN     NaN   NaN
# 31   NaN    NaN   NaN      NaN                   Lodi    NaN     NaN   NaN
# 32   NaN    NaN   NaN      NaN        Monterey County    NaN     NaN   NaN
# 33   NaN    NaN   NaN      NaN          Sonoma County    NaN     NaN   NaN
# 34   NaN    NaN   NaN      NaN       Dry Creek Valley    NaN     NaN   NaN
# 35   NaN    NaN   NaN      NaN            Paso Robles    NaN     NaN   NaN
# 36   NaN    NaN   NaN      NaN                 Oregon    NaN     NaN   NaN
# 37   NaN    NaN   NaN      NaN          Central Coast    NaN     NaN   NaN
# 38   NaN    NaN   NaN      NaN               Carneros    NaN     NaN   NaN
# 39   NaN    NaN   NaN      NaN          Sonoma Valley    NaN     NaN   NaN
#
#    description type
# 0          NaN  NaN
# 1          NaN  NaN
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN
# 5          NaN  NaN
# 6          NaN  NaN
# 7          NaN  NaN
# 8          NaN  NaN
# 9          NaN  NaN
# 10         NaN  NaN
# 11         NaN  NaN
# 12         NaN  NaN
# 13         NaN  NaN
# 14         NaN  NaN
# 15         NaN  NaN
# 16         NaN  NaN
# 17         NaN  NaN
# 18         NaN  NaN
# 19         NaN  NaN
# 20         NaN  NaN
# 21         NaN  NaN
# 22         NaN  NaN
# 23         NaN  NaN
# 24         NaN  NaN
# 25         NaN  NaN
# 26         NaN  NaN
# 27         NaN  NaN
# 28         NaN  NaN
# 29         NaN  NaN
# 30         NaN  NaN
# 31         NaN  NaN
# 32         NaN  NaN
# 33         NaN  NaN
# 34         NaN  NaN
# 35         NaN  NaN
# 36         NaN  NaN
# 37         NaN  NaN
# 38         NaN  NaN
# 39         NaN  NaN

# %%
# Drop unnecessary columns and duplicates
region_df = location_wine_df.drop(columns = ['index','description', 'points', 'price', 'province',
                                             'title', 'variety', 'winery','type'], axis = 1)
region_df
# Out:
#                  region_1
# 0    Russian River Valley
# 1         Anderson Valley
# 2         Sta. Rita Hills
# 3    Santa Cruz Mountains
# 4      Chehalem Mountains
# 5            Sonoma Coast
# 6        Mendocino County
# 7             Napa Valley
# 8           Wahluke Slope
# 9        Sierra Foothills
# 10          Yakima Valley
# 11           Red Mountain
# 12      Willamette Valley
# 13   Santa Barbara County
# 14    Walla Walla Valley
# 15     Horse Heaven Hills
# 16       Alexander Valley
# 17            Edna Valley
# 18       Livermore Valley
# 19       Columbia Valley
# 20            North Coast
# 21             Rutherford
# 22               Monterey
# 23             Washington
# 24              Mendocino
# 25           Dundee Hills
# 26           Rogue Valley
# 27      Santa Ynez Valley
# 28  Santa Lucia Highlands
# 29     Santa Maria Valley
# 30             California
# 31                   Lodi
# 32        Monterey County
# 33          Sonoma County
# 34       Dry Creek Valley
# 35            Paso Robles
# 36                 Oregon
# 37          Central Coast
# 38               Carneros
# 39          Sonoma Valley

# %%
region_df.dropna(inplace=True)

# %%
# Create a region list
region_list = list(region_df['region_1'])
print(len(region_list))
region_list
# Out:
# 40
# ['Russian River Valley',
#  'Anderson Valley',
#  'Sta. Rita Hills',
#  'Santa Cruz Mountains',
#  'Chehalem Mountains',
#  'Sonoma Coast',
#  'Mendocino County',
#  'Napa Valley',
#  'Wahluke Slope',
#  'Sierra Foothills',
#  'Yakima Valley',
#  'Red Mountain',
#  'Willamette Valley',
#  'Santa Barbara County',
#  'Walla Walla Valley ',
#  'Horse Heaven Hills',
#  'Alexander Valley',
#  'Edna Valley',
#  'Livermore Valley',
#  'Columbia Valley ',
#  'North Coast',
#  'Rutherford',
#  'Monterey',
#  'Washington',
#  'Mendocino',
#  'Dundee Hills',
#  'Rogue Valley',
#  'Santa Ynez Valley',
#  'Santa Lucia Highlands',
#  'Santa Maria Valley',
#  'California',
#  'Lodi',
#  'Monterey County',
#  'Sonoma County',
#  'Dry Creek Valley',
#  'Paso Robles',
#  'Oregon',
#  'Central Coast',
#  'Carneros',
#  'Sonoma Valley']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?inputtype=textquery&key='+ gkey

# %%
# Format regions to a string
regions = str(region_df)
regions.format
# Out:
# <function str.format>

# %%
# Create an empty list to hold the region data.
place_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the regions in the list.
for i, region in enumerate(region_list):

 # Group regions in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    placeid_url = valley_url + '&input='+ region
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the region.
    print(f"Processing Record {record_count} of Set {set_count} | {region}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for each of the regions.
    try:
        # Parse the JSON and retrieve data.
        region_url = requests.get(placeid_url).json()
        # Parse out the needed data.
        place_id = region_url['candidates'][0]['place_id']
        # Append the region information into place_id_data list.
        place_id_data.append({"region": region, 
                              "Place_id": place_id})

# If an error is experienced, skip the region.
    except:
        print("region not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 16 of Set 1 | Russian River Valley
# Processing Record 17 of Set 1 | Anderson Valley
# Processing Record 18 of Set 1 | Sta. Rita Hills
# Processing Record 19 of Set 1 | Santa Cruz Mountains
# Processing Record 20 of Set 1 | Chehalem Mountains
# Processing Record 21 of Set 1 | Sonoma Coast
# Processing Record 22 of Set 1 | Mendocino County
# Processing Record 23 of Set 1 | Napa Valley
# Processing Record 24 of Set 1 | Wahluke Slope
# Processing Record 25 of Set 1 | Sierra Foothills
# Processing Record 26 of Set 1 | Yakima Valley
# Processing Record 27 of Set 1 | Red Mountain
# Processing Record 28 of Set 1 | Willamette Valley
# Processing Record 29 of Set 1 | Santa Barbara County
# Processing Record 30 of Set 1 | Walla Walla Valley
# Processing Record 31 of Set 1 | Horse Heaven Hills
# Processing Record 32 of Set 1 | Alexander Valley
# Processing Record 33 of Set 1 | Edna Valley
# Processing Record 34 of Set 1 | Livermore Valley
# Processing Record 35 of Set 1 | Columbia Valley
# Processing Record 36 of Set 1 | North Coast
# Processing Record 37 of Set 1 | Rutherford
# Processing Record 38 of Set 1 | Monterey
# Processing Record 39 of Set 1 | Washington
# Processing Record 40 of Set 1 | Mendocino
# Processing Record 41 of Set 1 | Dundee Hills
# Processing Record 42 of Set 1 | Rogue Valley
# Processing Record 43 of Set 1 | Santa Ynez Valley
# Processing Record 44 of Set 1 | Santa Lucia Highlands
# Processing Record 45 of Set 1 | Santa Maria Valley
# Processing Record 46 of Set 1 | California
# Processing Record 47 of Set 1 | Lodi
# Processing Record 48 of Set 1 | Monterey County
# Processing Record 49 of Set 1 | Sonoma County
# Processing Record 50 of Set 1 | Dry Creek Valley
# Processing Record 51 of Set 1 | Paso Robles
# Processing Record 52 of Set 1 | Oregon
# Processing Record 53 of Set 1 | Central Coast
# Processing Record 54 of Set 1 | Carneros
# Processing Record 55 of Set 1 | Sonoma Valley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create place_id dataframe
placeid_df = pd .DataFrame(place_id_data)
placeid_df.head(10)
# Out:
#                  region                     Place_id
# 0  Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 1       Anderson Valley  ChIJa8v27oYSgYARRA6kQu3ru5s
# 2       Sta. Rita Hills  ChIJt82dTpwe7IAR9oK1FQs83rg
# 3  Santa Cruz Mountains  ChIJV7FWSmU7joARrCMjR_-QG_4
# 4    Chehalem Mountains  ChIJZznzuJsVlVQRY3ZPAz77fTk
# 5          Sonoma Coast  ChIJB8Hkg3mehoARNDJoq9RCScI
# 6      Mendocino County  ChIJh-hRvjCOgYARFQFu8mmzZyM
# 7           Napa Valley  ChIJMU8qI_lPhIARfMUQoxvSFP4
# 8         Wahluke Slope  ChIJV96zdT2umVQRoqO1RPkJ1JU
# 9      Sierra Foothills  ChIJ26Z6dJzqQIYRGkZw82ndznI

# %%
# Create place_id list
place_id_list = list(placeid_df['Place_id'])
print(len(place_id_list))
# Out:
# 55
# ['ChIJhddrQaV7gYAR0SLRbKP8lNc',
#  'ChIJa8v27oYSgYARRA6kQu3ru5s',
#  'ChIJt82dTpwe7IAR9oK1FQs83rg',
#  'ChIJV7FWSmU7joARrCMjR_-QG_4',
#  'ChIJZznzuJsVlVQRY3ZPAz77fTk',
#  'ChIJB8Hkg3mehoARNDJoq9RCScI',
#  'ChIJh-hRvjCOgYARFQFu8mmzZyM',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJV96zdT2umVQRoqO1RPkJ1JU',
#  'ChIJ26Z6dJzqQIYRGkZw82ndznI',
#  'ChIJtwIWxMKHl1QR30xHsvUB3dI',
#  'ChIJGymYhV8ZiYgRnTFqxjQrKIQ',
#  'ChIJbezwJP6hlVQRBDL4exvIWSo',
#  'ChIJXxfrQWYM7IAR_9ACRVau1Wo',
#  'ChIJBwOnamNqolQRlUFeGjkeZrc',
#  'ChIJhddrQaV7gYAR0SLRbKP8lNc',
#  'ChIJa8v27oYSgYARRA6kQu3ru5s',
#  'ChIJt82dTpwe7IAR9oK1FQs83rg',
#  'ChIJV7FWSmU7joARrCMjR_-QG_4',
#  'ChIJZznzuJsVlVQRY3ZPAz77fTk',
#  'ChIJB8Hkg3mehoARNDJoq9RCScI',
#  'ChIJh-hRvjCOgYARFQFu8mmzZyM',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJV96zdT2umVQRoqO1RPkJ1JU',
#  'ChIJ26Z6dJzqQIYRGkZw82ndznI',
#  'ChIJtwIWxMKHl1QR30xHsvUB3dI',
#  'ChIJGymYhV8ZiYgRnTFqxjQrKIQ',
#  'ChIJbezwJP6hlVQRBDL4exvIWSo',
#  'ChIJXxfrQWYM7IAR_9ACRVau1Wo',
#  'ChIJBwOnamNqolQRlUFeGjkeZrc',
#  'ChIJJSIr8a0cmFQRZIWx0ZnZtlo',
#  'ChIJD2TljFMUhIARBOZe4vCoE7o',
#  'ChIJ00tXuZzAQIYRIR-pBinC7rE',
#  'ChIJyTz6fqDnj4ARImnwYa7AE3E',
#  'ChIJU2oMa7zAQIYRkEg9eGVDXnE',
#  'ChIJcQw3BfvBQIYRVxfy2ZR7dx0',
#  'ChIJkUqt1aP4wokRAB032V1oBsw',
#  'ChIJkfu1cFLkjYARXj1K2AlJSO4',
#  'ChIJ-bDD5__lhVQRuvNfbGh4QpQ',
#  'ChIJM-tWPGuygYARO7PAQfKXD9Y',
#  'ChIJ38rsT3DFQIYRljs8vSsd23o',
#  'ChIJg3cxDPaHxVQRde0DiGnDILs',
#  'ChIJH3v79pZT6YAR-MXTvZmd134',
#  'ChIJY2jxLkBukoARNMBojauvJF8',
#  'ChIJuSa1m68U7IARhOJOSOcz2gA',
#  'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#  'ChIJNTjFJtmhmoARRuhsu5jkrY4',
#  'ChIJUV7XWK6z7IARFNInOyD3gBc',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJ1xNSFmTBQIYRBDAiMLUJ-nI',
#  'ChIJvcTFFo_d7IAR79XMkfgilEY',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJKc3y6rn_01QRShgXeMPA-1c',
#  'ChIJc91fIoDbRIYR_iZWpJpCMiE',
#  'ChIJI-UCgdlShIARPnjSSZd4foM']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url2 = ('https://maps.googleapis.com/maps/api/place/details/json?&key='+ gkey)

# %%
# Create an empty list to hold the coord data.
coord_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the place ids in the list.
for i, placeids in enumerate(place_id_list):

 # Group place ids in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    coord_url = valley_url2 + '&place_id='+ placeids
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the place ids.
    print(f"Processing Record {record_count} of Set {set_count} | {placeids}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for the place ids and retrieve the lat long info.
    try:
        # Parse the JSON and retrieve data.
        geo_url = requests.get(coord_url).json()
        # Parse out the needed data.
        lat_id = geo_url['result']['geometry']['location']['lat']
        long_id = geo_url['result']['geometry']['location']['lng']
        # Append the region information into place_id_data list.
        coord_id_data.append({"Place_id": placeids, 
                              "Latitude": lat_id,
                             "Longitude": long_id})
        


# If an error is experienced, skip the record.
    except:
        print("record not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ChIJhddrQaV7gYAR0SLRbKP8lNc
# Processing Record 2 of Set 1 | ChIJa8v27oYSgYARRA6kQu3ru5s
# Processing Record 3 of Set 1 | ChIJt82dTpwe7IAR9oK1FQs83rg
# Processing Record 4 of Set 1 | ChIJV7FWSmU7joARrCMjR_-QG_4
# Processing Record 5 of Set 1 | ChIJZznzuJsVlVQRY3ZPAz77fTk
# Processing Record 6 of Set 1 | ChIJB8Hkg3mehoARNDJoq9RCScI
# Processing Record 7 of Set 1 | ChIJh-hRvjCOgYARFQFu8mmzZyM
# Processing Record 8 of Set 1 | ChIJMU8qI_lPhIARfMUQoxvSFP4
# Processing Record 9 of Set 1 | ChIJV96zdT2umVQRoqO1RPkJ1JU
# Processing Record 10 of Set 1 | ChIJ26Z6dJzqQIYRGkZw82ndznI
# Processing Record 11 of Set 1 | ChIJtwIWxMKHl1QR30xHsvUB3dI
# Processing Record 12 of Set 1 | ChIJGymYhV8ZiYgRnTFqxjQrKIQ
# Processing Record 13 of Set 1 | ChIJbezwJP6hlVQRBDL4exvIWSo
# Processing Record 14 of Set 1 | ChIJXxfrQWYM7IAR_9ACRVau1Wo
# Processing Record 15 of Set 1 | ChIJBwOnamNqolQRlUFeGjkeZrc
# Processing Record 16 of Set 1 | ChIJhddrQaV7gYAR0SLRbKP8lNc
# Processing Record 17 of Set 1 | ChIJa8v27oYSgYARRA6kQu3ru5s
# Processing Record 18 of Set 1 | ChIJt82dTpwe7IAR9oK1FQs83rg
# Processing Record 19 of Set 1 | ChIJV7FWSmU7joARrCMjR_-QG_4
# Processing Record 20 of Set 1 | ChIJZznzuJsVlVQRY3ZPAz77fTk
# Processing Record 21 of Set 1 | ChIJB8Hkg3mehoARNDJoq9RCScI
# Processing Record 22 of Set 1 | ChIJh-hRvjCOgYARFQFu8mmzZyM
# Processing Record 23 of Set 1 | ChIJMU8qI_lPhIARfMUQoxvSFP4
# Processing Record 24 of Set 1 | ChIJV96zdT2umVQRoqO1RPkJ1JU
# Processing Record 25 of Set 1 | ChIJ26Z6dJzqQIYRGkZw82ndznI
# Processing Record 1 of Set 2 | ChIJtwIWxMKHl1QR30xHsvUB3dI
# Processing Record 2 of Set 2 | ChIJGymYhV8ZiYgRnTFqxjQrKIQ
# Processing Record 3 of Set 2 | ChIJbezwJP6hlVQRBDL4exvIWSo
# Processing Record 4 of Set 2 | ChIJXxfrQWYM7IAR_9ACRVau1Wo
# Processing Record 5 of Set 2 | ChIJBwOnamNqolQRlUFeGjkeZrc
# Processing Record 6 of Set 2 | ChIJJSIr8a0cmFQRZIWx0ZnZtlo
# Processing Record 7 of Set 2 | ChIJD2TljFMUhIARBOZe4vCoE7o
# Processing Record 8 of Set 2 | ChIJ00tXuZzAQIYRIR-pBinC7rE
# Processing Record 9 of Set 2 | ChIJyTz6fqDnj4ARImnwYa7AE3E
# Processing Record 10 of Set 2 | ChIJU2oMa7zAQIYRkEg9eGVDXnE
# Processing Record 11 of Set 2 | ChIJcQw3BfvBQIYRVxfy2ZR7dx0
# Processing Record 12 of Set 2 | ChIJkUqt1aP4wokRAB032V1oBsw
# Processing Record 13 of Set 2 | ChIJkfu1cFLkjYARXj1K2AlJSO4
# Processing Record 14 of Set 2 | ChIJ-bDD5__lhVQRuvNfbGh4QpQ
# Processing Record 15 of Set 2 | ChIJM-tWPGuygYARO7PAQfKXD9Y
# Processing Record 16 of Set 2 | ChIJ38rsT3DFQIYRljs8vSsd23o
# Processing Record 17 of Set 2 | ChIJg3cxDPaHxVQRde0DiGnDILs
# Processing Record 18 of Set 2 | ChIJH3v79pZT6YAR-MXTvZmd134
# Processing Record 19 of Set 2 | ChIJY2jxLkBukoARNMBojauvJF8
# Processing Record 20 of Set 2 | ChIJuSa1m68U7IARhOJOSOcz2gA
# Processing Record 21 of Set 2 | ChIJPV4oX_65j4ARVW8IJ6IJUYs
# Processing Record 22 of Set 2 | ChIJNTjFJtmhmoARRuhsu5jkrY4
# Processing Record 23 of Set 2 | ChIJUV7XWK6z7IARFNInOyD3gBc
# Processing Record 24 of Set 2 | ChIJj7atfV0ihIAR_qYnBSATSUk
# Processing Record 25 of Set 2 | ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# Processing Record 1 of Set 3 | ChIJvcTFFo_d7IAR79XMkfgilEY
# Processing Record 2 of Set 3 | ChIJVWqfm3xuk1QRdrgLettlTH0
# Processing Record 3 of Set 3 | ChIJKc3y6rn_01QRShgXeMPA-1c
# Processing Record 4 of Set 3 | ChIJc91fIoDbRIYR_iZWpJpCMiE
# Processing Record 5 of Set 3 | ChIJI-UCgdlShIARPnjSSZd4foM
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a coordinate dataframe
coord_df = pd.DataFrame(coord_id_data)
coord_df.head(10)
# Out:
#                       Place_id   Latitude   Longitude
# 0  ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# 1  ChIJa8v27oYSgYARRA6kQu3ru5s  39.086566 -123.479454
# 2  ChIJt82dTpwe7IAR9oK1FQs83rg  34.665957 -120.115241
# 3  ChIJV7FWSmU7joARrCMjR_-QG_4  37.110892 -121.844891
# 4  ChIJZznzuJsVlVQRY3ZPAz77fTk  45.376228 -123.037326
# 5  ChIJB8Hkg3mehoARNDJoq9RCScI  38.424211 -123.101173
# 6  ChIJh-hRvjCOgYARFQFu8mmzZyM  39.550019 -123.438353
# 7  ChIJMU8qI_lPhIARfMUQoxvSFP4  38.502469 -122.265389
# 8  ChIJV96zdT2umVQRoqO1RPkJ1JU  46.749893 -119.834210
# 9  ChIJ26Z6dJzqQIYRGkZw82ndznI  29.672680  -95.421386

# %%
# Join the place_id and coord dataframes
region_df = pd.concat([placeid_df, coord_df], axis=1, join="inner")
    
region_df
# Out:
#                    region                     Place_id  \
# 0    Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 1         Anderson Valley  ChIJa8v27oYSgYARRA6kQu3ru5s
# 2         Sta. Rita Hills  ChIJt82dTpwe7IAR9oK1FQs83rg
# 3    Santa Cruz Mountains  ChIJV7FWSmU7joARrCMjR_-QG_4
# 4      Chehalem Mountains  ChIJZznzuJsVlVQRY3ZPAz77fTk
# 5            Sonoma Coast  ChIJB8Hkg3mehoARNDJoq9RCScI
# 6        Mendocino County  ChIJh-hRvjCOgYARFQFu8mmzZyM
# 7             Napa Valley  ChIJMU8qI_lPhIARfMUQoxvSFP4
# 8           Wahluke Slope  ChIJV96zdT2umVQRoqO1RPkJ1JU
# 9        Sierra Foothills  ChIJ26Z6dJzqQIYRGkZw82ndznI
# 10          Yakima Valley  ChIJtwIWxMKHl1QR30xHsvUB3dI
# 11           Red Mountain  ChIJGymYhV8ZiYgRnTFqxjQrKIQ
# 12      Willamette Valley  ChIJbezwJP6hlVQRBDL4exvIWSo
# 13   Santa Barbara County  ChIJXxfrQWYM7IAR_9ACRVau1Wo
# 14    Walla Walla Valley   ChIJBwOnamNqolQRlUFeGjkeZrc
# 15   Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 16        Anderson Valley  ChIJa8v27oYSgYARRA6kQu3ru5s
# 17        Sta. Rita Hills  ChIJt82dTpwe7IAR9oK1FQs83rg
# 18   Santa Cruz Mountains  ChIJV7FWSmU7joARrCMjR_-QG_4
# 19     Chehalem Mountains  ChIJZznzuJsVlVQRY3ZPAz77fTk
# 20           Sonoma Coast  ChIJB8Hkg3mehoARNDJoq9RCScI
# 21       Mendocino County  ChIJh-hRvjCOgYARFQFu8mmzZyM
# 22            Napa Valley  ChIJMU8qI_lPhIARfMUQoxvSFP4
# 23          Wahluke Slope  ChIJV96zdT2umVQRoqO1RPkJ1JU
# 24       Sierra Foothills  ChIJ26Z6dJzqQIYRGkZw82ndznI
# 25          Yakima Valley  ChIJtwIWxMKHl1QR30xHsvUB3dI
# 26           Red Mountain  ChIJGymYhV8ZiYgRnTFqxjQrKIQ
# 27      Willamette Valley  ChIJbezwJP6hlVQRBDL4exvIWSo
# 28   Santa Barbara County  ChIJXxfrQWYM7IAR_9ACRVau1Wo
# 29    Walla Walla Valley   ChIJBwOnamNqolQRlUFeGjkeZrc
# 30     Horse Heaven Hills  ChIJJSIr8a0cmFQRZIWx0ZnZtlo
# 31       Alexander Valley  ChIJD2TljFMUhIARBOZe4vCoE7o
# 32            Edna Valley  ChIJ00tXuZzAQIYRIR-pBinC7rE
# 33       Livermore Valley  ChIJyTz6fqDnj4ARImnwYa7AE3E
# 34       Columbia Valley   ChIJU2oMa7zAQIYRkEg9eGVDXnE
# 35            North Coast  ChIJcQw3BfvBQIYRVxfy2ZR7dx0
# 36             Rutherford  ChIJkUqt1aP4wokRAB032V1oBsw
# 37               Monterey  ChIJkfu1cFLkjYARXj1K2AlJSO4
# 38             Washington  ChIJ-bDD5__lhVQRuvNfbGh4QpQ
# 39              Mendocino  ChIJM-tWPGuygYARO7PAQfKXD9Y
# 40           Dundee Hills  ChIJ38rsT3DFQIYRljs8vSsd23o
# 41           Rogue Valley  ChIJg3cxDPaHxVQRde0DiGnDILs
# 42      Santa Ynez Valley  ChIJH3v79pZT6YAR-MXTvZmd134
# 43  Santa Lucia Highlands  ChIJY2jxLkBukoARNMBojauvJF8
# 44     Santa Maria Valley  ChIJuSa1m68U7IARhOJOSOcz2gA
# 45             California  ChIJPV4oX_65j4ARVW8IJ6IJUYs
# 46                   Lodi  ChIJNTjFJtmhmoARRuhsu5jkrY4
# 47        Monterey County  ChIJUV7XWK6z7IARFNInOyD3gBc
# 48          Sonoma County  ChIJj7atfV0ihIAR_qYnBSATSUk
# 49       Dry Creek Valley  ChIJ1xNSFmTBQIYRBDAiMLUJ-nI
# 50            Paso Robles  ChIJvcTFFo_d7IAR79XMkfgilEY
# 51                 Oregon  ChIJVWqfm3xuk1QRdrgLettlTH0
# 52          Central Coast  ChIJKc3y6rn_01QRShgXeMPA-1c
# 53               Carneros  ChIJc91fIoDbRIYR_iZWpJpCMiE
# 54          Sonoma Valley  ChIJI-UCgdlShIARPnjSSZd4foM
#
#                        Place_id   Latitude   Longitude
# 0   ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# 1   ChIJa8v27oYSgYARRA6kQu3ru5s  39.086566 -123.479454
# 2   ChIJt82dTpwe7IAR9oK1FQs83rg  34.665957 -120.115241
# 3   ChIJV7FWSmU7joARrCMjR_-QG_4  37.110892 -121.844891
# 4   ChIJZznzuJsVlVQRY3ZPAz77fTk  45.376228 -123.037326
# 5   ChIJB8Hkg3mehoARNDJoq9RCScI  38.424211 -123.101173
# 6   ChIJh-hRvjCOgYARFQFu8mmzZyM  39.550019 -123.438353
# 7   ChIJMU8qI_lPhIARfMUQoxvSFP4  38.502469 -122.265389
# 8   ChIJV96zdT2umVQRoqO1RPkJ1JU  46.749893 -119.834210
# 9   ChIJ26Z6dJzqQIYRGkZw82ndznI  29.672680  -95.421386
# 10  ChIJtwIWxMKHl1QR30xHsvUB3dI  46.328906 -120.008639
# 11  ChIJGymYhV8ZiYgRnTFqxjQrKIQ  33.486471  -86.803901
# 12  ChIJbezwJP6hlVQRBDL4exvIWSo  44.942554 -122.933762
# 13  ChIJXxfrQWYM7IAR_9ACRVau1Wo  34.420832 -119.698206
# 14  ChIJBwOnamNqolQRlUFeGjkeZrc  46.065595 -118.338743
# 15  ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# 16  ChIJa8v27oYSgYARRA6kQu3ru5s  39.086566 -123.479454
# 17  ChIJt82dTpwe7IAR9oK1FQs83rg  34.665957 -120.115241
# 18  ChIJV7FWSmU7joARrCMjR_-QG_4  37.110892 -121.844891
# 19  ChIJZznzuJsVlVQRY3ZPAz77fTk  45.376228 -123.037326
# 20  ChIJB8Hkg3mehoARNDJoq9RCScI  38.424211 -123.101173
# 21  ChIJh-hRvjCOgYARFQFu8mmzZyM  39.550019 -123.438353
# 22  ChIJMU8qI_lPhIARfMUQoxvSFP4  38.502469 -122.265389
# 23  ChIJV96zdT2umVQRoqO1RPkJ1JU  46.749893 -119.834210
# 24  ChIJ26Z6dJzqQIYRGkZw82ndznI  29.672680  -95.421386
# 25  ChIJtwIWxMKHl1QR30xHsvUB3dI  46.328906 -120.008639
# 26  ChIJGymYhV8ZiYgRnTFqxjQrKIQ  33.486471  -86.803901
# 27  ChIJbezwJP6hlVQRBDL4exvIWSo  44.942554 -122.933762
# 28  ChIJXxfrQWYM7IAR_9ACRVau1Wo  34.420832 -119.698206
# 29  ChIJBwOnamNqolQRlUFeGjkeZrc  46.065595 -118.338743
# 30  ChIJJSIr8a0cmFQRZIWx0ZnZtlo  46.133188 -119.867814
# 31  ChIJD2TljFMUhIARBOZe4vCoE7o  38.612965 -122.769435
# 32  ChIJ00tXuZzAQIYRIR-pBinC7rE  29.738032  -95.398174
# 33  ChIJyTz6fqDnj4ARImnwYa7AE3E  37.688744 -121.791351
# 34  ChIJU2oMa7zAQIYRkEg9eGVDXnE  29.752715  -95.408215
# 35  ChIJcQw3BfvBQIYRVxfy2ZR7dx0  29.747997  -95.407689
# 36  ChIJkUqt1aP4wokRAB032V1oBsw  40.826489  -74.106809
# 37  ChIJkfu1cFLkjYARXj1K2AlJSO4  36.600238 -121.894676
# 38  ChIJ-bDD5__lhVQRuvNfbGh4QpQ  47.751074 -120.740139
# 39  ChIJM-tWPGuygYARO7PAQfKXD9Y  39.307674 -123.799459
# 40  ChIJ38rsT3DFQIYRljs8vSsd23o  29.765838  -95.551601
# 41  ChIJg3cxDPaHxVQRde0DiGnDILs  42.440125 -122.926155
# 42  ChIJH3v79pZT6YAR-MXTvZmd134  34.584154 -120.097369
# 43  ChIJY2jxLkBukoARNMBojauvJF8  36.430771 -121.420375
# 44  ChIJuSa1m68U7IARhOJOSOcz2gA  34.898383 -120.443036
# 45  ChIJPV4oX_65j4ARVW8IJ6IJUYs  36.778261 -119.417932
# 46  ChIJNTjFJtmhmoARRuhsu5jkrY4  38.134148 -121.272219
# 47  ChIJUV7XWK6z7IARFNInOyD3gBc  36.313620 -121.354163
# 48  ChIJj7atfV0ihIAR_qYnBSATSUk  38.577956 -122.988832
# 49  ChIJ1xNSFmTBQIYRBDAiMLUJ-nI  29.738575  -95.471458
# 50  ChIJvcTFFo_d7IAR79XMkfgilEY  35.636876 -120.654502
# 51  ChIJVWqfm3xuk1QRdrgLettlTH0  43.804133 -120.554201
# 52  ChIJKc3y6rn_01QRShgXeMPA-1c  40.783448 -124.140008
# 53  ChIJc91fIoDbRIYR_iZWpJpCMiE  30.491573  -97.591876
# 54  ChIJI-UCgdlShIARPnjSSZd4foM  38.366880 -122.497482

# %%
# Drop Place_id column
region_df = region_df.drop(['Place_id'], axis=1)
region_df
# Out:
#                    region   Latitude   Longitude
# 0    Russian River Valley  38.911980 -123.053708
# 1         Anderson Valley  39.086566 -123.479454
# 2         Sta. Rita Hills  34.665957 -120.115241
# 3    Santa Cruz Mountains  37.110892 -121.844891
# 4      Chehalem Mountains  45.376228 -123.037326
# 5            Sonoma Coast  38.424211 -123.101173
# 6        Mendocino County  39.550019 -123.438353
# 7             Napa Valley  38.502469 -122.265389
# 8           Wahluke Slope  46.749893 -119.834210
# 9        Sierra Foothills  29.672680  -95.421386
# 10          Yakima Valley  46.328906 -120.008639
# 11           Red Mountain  33.486471  -86.803901
# 12      Willamette Valley  44.942554 -122.933762
# 13   Santa Barbara County  34.420832 -119.698206
# 14    Walla Walla Valley   46.065595 -118.338743
# 15   Russian River Valley  38.911980 -123.053708
# 16        Anderson Valley  39.086566 -123.479454
# 17        Sta. Rita Hills  34.665957 -120.115241
# 18   Santa Cruz Mountains  37.110892 -121.844891
# 19     Chehalem Mountains  45.376228 -123.037326
# 20           Sonoma Coast  38.424211 -123.101173
# 21       Mendocino County  39.550019 -123.438353
# 22            Napa Valley  38.502469 -122.265389
# 23          Wahluke Slope  46.749893 -119.834210
# 24       Sierra Foothills  29.672680  -95.421386
# 25          Yakima Valley  46.328906 -120.008639
# 26           Red Mountain  33.486471  -86.803901
# 27      Willamette Valley  44.942554 -122.933762
# 28   Santa Barbara County  34.420832 -119.698206
# 29    Walla Walla Valley   46.065595 -118.338743
# 30     Horse Heaven Hills  46.133188 -119.867814
# 31       Alexander Valley  38.612965 -122.769435
# 32            Edna Valley  29.738032  -95.398174
# 33       Livermore Valley  37.688744 -121.791351
# 34       Columbia Valley   29.752715  -95.408215
# 35            North Coast  29.747997  -95.407689
# 36             Rutherford  40.826489  -74.106809
# 37               Monterey  36.600238 -121.894676
# 38             Washington  47.751074 -120.740139
# 39              Mendocino  39.307674 -123.799459
# 40           Dundee Hills  29.765838  -95.551601
# 41           Rogue Valley  42.440125 -122.926155
# 42      Santa Ynez Valley  34.584154 -120.097369
# 43  Santa Lucia Highlands  36.430771 -121.420375
# 44     Santa Maria Valley  34.898383 -120.443036
# 45             California  36.778261 -119.417932
# 46                   Lodi  38.134148 -121.272219
# 47        Monterey County  36.313620 -121.354163
# 48          Sonoma County  38.577956 -122.988832
# 49       Dry Creek Valley  29.738575  -95.471458
# 50            Paso Robles  35.636876 -120.654502
# 51                 Oregon  43.804133 -120.554201
# 52          Central Coast  40.783448 -124.140008
# 53               Carneros  30.491573  -97.591876
# 54          Sonoma Valley  38.366880 -122.497482

# %%
# Create connection string
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5434/WineEnthusiast"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Save the region_df DataFrame to a SQL table called wineregions
region_df.to_sql(name='wineregion', con=engine)

# %%
region_df.to_csv("Data/region_df.csv", index=False)
