# %%
# Dependencies to pull API
import requests
import json
# Google developer API key
from config import gkey

# %%
# Import Dependencies for Database
from config import password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import psycopg2
import pandas as pd
import time

# %%
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
engine = create_engine(db_string)
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['uswine', 'winedata', 'wine', 'winedata_ml', 'wineregions']

# %%
connection = engine.connect
session = Session(engine)
engine.execute("SELECT * from wine")

# %%
col_names_list = []

for i in range(len(inspector.get_columns('wine'))):
    col_names_list.append(inspector.get_columns('wine')[i]['name'])
    
print(col_names_list)
# Out:
# ['index', 'description', 'points', 'price', 'province', 'region_1', 'region_2', 'title', 'variety', 'winery']

# %%
location_wine_df = pd.DataFrame(columns = col_names_list)
location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
       'region_2', 'title', 'variety', 'winery'], axis = 1)
# Out:
# Empty DataFrame
# Columns: [index, region_1]
# Index: []

# %%
# Inner join for wines and regions
import sys
join_db = engine.execute("SELECT DISTINCT region_1 from wine")
for record in join_db:
    record_series = pd.Series((record), index = location_wine_df.columns)
    
    location_wine_df = location_wine_df.append(record_series, ignore_index=True, verify_integrity = True)

# %%
# Display df columns
location_wine_df
# Out:
#     index description points price province                  region_1  \
# 0     NaN         NaN    NaN   NaN      NaN      Russian River Valley
# 1     NaN         NaN    NaN   NaN      NaN            Clements Hills
# 2     NaN         NaN    NaN   NaN      NaN           Temecula Valley
# 3     NaN         NaN    NaN   NaN      NaN      Columbia Valley (WA)
# 4     NaN         NaN    NaN   NaN      NaN                    Nevada
# ..    ...         ...    ...   ...      ...                       ...
# 261   NaN         NaN    NaN   NaN      NaN    San Luis Obispo County
# 262   NaN         NaN    NaN   NaN      NaN  Southeastern New England
# 263   NaN         NaN    NaN   NaN      NaN              Marin County
# 264   NaN         NaN    NaN   NaN      NaN                     Texas
# 265   NaN         NaN    NaN   NaN      NaN               Lake County
#
#     region_2 title variety winery
# 0        NaN   NaN     NaN    NaN
# 1        NaN   NaN     NaN    NaN
# 2        NaN   NaN     NaN    NaN
# 3        NaN   NaN     NaN    NaN
# 4        NaN   NaN     NaN    NaN
# ..       ...   ...     ...    ...
# 261      NaN   NaN     NaN    NaN
# 262      NaN   NaN     NaN    NaN
# 263      NaN   NaN     NaN    NaN
# 264      NaN   NaN     NaN    NaN
# 265      NaN   NaN     NaN    NaN
#
# [266 rows x 10 columns]

# %%
# Drop unnecessary columns and duplicates
region_df = location_wine_df.drop(columns = ['description', 'points', 'price', 'province',
       'region_2', 'title', 'variety', 'winery'], axis = 1)
region_df
# Out:
#     index                  region_1
# 0     NaN      Russian River Valley
# 1     NaN            Clements Hills
# 2     NaN           Temecula Valley
# 3     NaN      Columbia Valley (WA)
# 4     NaN                    Nevada
# ..    ...                       ...
# 261   NaN    San Luis Obispo County
# 262   NaN  Southeastern New England
# 263   NaN              Marin County
# 264   NaN                     Texas
# 265   NaN               Lake County
#
# [266 rows x 2 columns]

# %%
# Create a region list
region_list = list(region_df['region_1'])
region_list
# Out:
# ['Russian River Valley',
#  'Clements Hills',
#  'Temecula Valley',
#  'Columbia Valley (WA)',
#  'Nevada',
#  'Anderson Valley',
#  'Solano County',
#  'New Mexico',
#  'Sonoma County-Monterey County-Napa County',
#  'North Coast',
#  'Puget Sound',
#  'Fair Play',
#  'Rutherford',
#  'Washington',
#  'Kentucky',
#  'Sonoma County-Monterey County-Santa Barbara County',
#  'Sonoma Mountain',
#  'Monterey-Santa Barbara-Sonoma',
#  'Calaveras County',
#  'San Luis Obispo',
#  'Eola-Amity Hills',
#  'Sonoita',
#  'Napa County-Lake County',
#  'Mendocino Ridge',
#  'Yolo County',
#  'Los Carneros',
#  'Napa County',
#  'Red Hills Lake County',
#  'Napa-Sonoma',
#  'Central Coast',
#  'Walla Walla Valley (WA)',
#  'Elkton Oregon',
#  'Oak Knoll District',
#  'Madera',
#  'California Other',
#  'San Antonio Valley',
#  'Ventura County',
#  'Columbia Valley-Walla Walla Valley',
#  'Santa Clara County',
#  'Chehalem Mountains',
#  'Napa Valley',
#  'Chalone',
#  'Napa-Amador',
#  'Mount Harlan',
#  'Cucamonga Valley',
#  'Horse Heaven Hills',
#  'Lake Chelan',
#  'Old Mission Peninsula',
#  'Paso Robles Willow Creek District',
#  'Oakville',
#  'Sonoma-Mendocino',
#  'Finger Lakes',
#  'Mt. Harlan',
#  'Tehama County',
#  'Redwood Valley',
#  'Sonoma-Napa-Mendocino',
#  'Santa Barbara-Monterey',
#  'Happy Canyon of Santa Barbara',
#  'Santa Barbara',
#  'Adelaida District',
#  'Howell Mountain',
#  'Sonoma County-San Joaquin County',
#  'Rattlesnake Hills',
#  'McDowell Valley',
#  'Green Valley',
#  'Dry Creek Valley',
#  'Moon Mountain District Sonoma County',
#  'San Francisco Bay',
#  'Sonoma Valley',
#  'Lake-Sonoma-Napa',
#  'Carmel Valley',
#  'Augusta',
#  'New York',
#  'Hawaii',
#  'Ribbon Ridge',
#  'El Dorado County',
#  'Napa-Sonoma-Marin',
#  'Santa Margarita Ranch',
#  'Napa-Mendocino-Sonoma-Marin',
#  'Ohio',
#  'Northern Sonoma',
#  'Kelsey Bench-Lake County',
#  'River Junction',
#  'Ben Lomond Mountain',
#  'Outer Coastal Plain',
#  'St. Helena',
#  'Lodi',
#  'Sonoma County',
#  'Long Island',
#  'Paso Robles',
#  'San Benito County',
#  "Virginia's Eastern Shore",
#  'Ballard Canyon',
#  'El Pomar District',
#  'Cienega Valley',
#  'Chelan County',
#  'Potter Valley',
#  'Sonoma County-Santa Barbara County',
#  'Napa',
#  'Sta. Rita Hills',
#  'Cayuga Lake',
#  'Yountville',
#  'Chalk Hill',
#  'Stags Leap District',
#  'Red Mountain',
#  'Clarksburg',
#  'Massachusetts',
#  'Napa-Carneros',
#  'Alexander Valley',
#  'Edna Valley',
#  'Napa Valley-Paso Robles',
#  'Monticello',
#  'Swan Creek',
#  'South Coast',
#  'Pennsylvania',
#  'Monterey-Santa Barbara',
#  'Humboldt County',
#  'Sonoma',
#  'Illinois',
#  'Virginia',
#  'San Diego County',
#  'Monterey County-Napa County-Sonoma County',
#  'Grand Valley',
#  'San Lucas',
#  'Columbia Gorge (WA)',
#  'Arroyo Seco',
#  'Templeton Gap District',
#  'Placer County',
#  'Paso Robles Highlands District',
#  'Central Valley',
#  'Isle St. George',
#  'Santa Clara Valley',
#  'Sonoma County-Monterey County',
#  'California-Oregon',
#  'Napa-Mendocino-Sonoma',
#  'Columbia Valley (OR)',
#  'Ancient Lakes',
#  'Yakima Valley',
#  'Atlas Peak',
#  'Polk County',
#  'Lime Kiln Valley',
#  'Malibu-Newton Canyon',
#  'Shenandoah Valley',
#  'Leelanau Peninsula',
#  'Alta Mesa',
#  'Malibu Coast',
#  'Sonoma County-Napa County',
#  'Rogue Valley',
#  'El Dorado',
#  'Santa Ynez Valley',
#  'Solano County Green Valley',
#  'Temecula',
#  'Mokelumne River',
#  'Santa Lucia Highlands',
#  'Umpqua Valley',
#  'Texoma',
#  'Amador-Napa',
#  'Guenoc Valley',
#  'Santa Maria Valley',
#  'North Fork of Long Island',
#  'Washington-Oregon',
#  'Seneca Lake',
#  'Calistoga',
#  'Oregon',
#  'Naches Heights',
#  'Idaho',
#  'Coombsville',
#  'Colorado',
#  'America',
#  'New Jersey',
#  'Sonoma-Napa',
#  'Saddle Rock-Malibu',
#  'Willamette Valley',
#  'Niagara Escarpment',
#  'Lake Erie',
#  'Monterey-San Luis Obispo-Santa Barbara',
#  'Michigan',
#  'Paicines',
#  'Oregon Other',
#  'Dundee Hills',
#  'Suisun Valley',
#  'Napa County-Sonoma County-San Joaquin County',
#  'Napa County-Sonoma County',
#  'California',
#  'Napa County-Sonoma County-Lake County',
#  'Lake Michigan Shore',
#  'Fort Ross-Seaview',
#  'Contra Costa County',
#  'Bennett Valley',
#  'Big Valley District-Lake County',
#  'San Francisco Bay-Livermore Valley',
#  'Nevada County',
#  'Vermont',
#  'Clear Lake',
#  'Santa Cruz Mountains',
#  'Yamhill County',
#  'Mendocino County',
#  'Capay Valley',
#  'Missouri',
#  'Yadkin Valley',
#  'Cochise County',
#  'Wahluke Slope',
#  'Dunnigan Hills',
#  'Sierra Foothills',
#  'Chiles Valley',
#  'Monterey County-Napa County',
#  'Southern Oregon',
#  'York Mountain',
#  'Mendocino-Amador',
#  'Livermore Valley',
#  'Mount Veeder',
#  'High Valley',
#  'Snipes Mountain',
#  'Western Connecticut Highlands',
#  'Sierra Pelona Valley',
#  'Arizona',
#  'Pine Mountain-Cloverdale Peak',
#  'Applegate Valley',
#  'Columbia Gorge (OR)',
#  'Amador County',
#  'Lake County-Sonoma County',
#  'Santa Cruz County',
#  'Carneros-Napa Valley',
#  'Lake County-Mendocino County',
#  'The Hamptons, Long Island',
#  'Sonoma-Santa Barbara-Mendocino',
#  'Spring Mountain District',
#  'Carneros',
#  'North Carolina',
#  'Texas High Plains',
#  'Ramona Valley',
#  'Hudson River Region',
#  'Cole Ranch',
#  'Sonoma Coast',
#  'San Bernabe',
#  'Yorkville Highlands',
#  'Mendocino-Lake',
#  'Grand River Valley',
#  'McMinnville',
#  'Iowa',
#  'Sonoma County-Lake County',
#  'Santa Barbara County',
#  'Columbia Valley',
#  'Monterey-Santa Cruz',
#  'Arroyo Grande Valley',
#  'Walla Walla Valley (OR)',
#  'Antelope Valley of the California High Desert',
#  'Napa-Monterey-Mendocino',
#  'Knights Valley',
#  'Tuolumne County',
#  'Monterey',
#  'Sonoma-Napa-Lake',
#  'Mendocino',
#  'Diamond Mountain District',
#  'Middleburg',
#  'Shenandoah Valley (CA)',
#  'Rockpile',
#  'Sonoma-Napa-Monterey',
#  'Fiddletown',
#  'Mendocino-Lake County-Napa',
#  'Monterey County',
#  'San Luis Obispo County',
#  'Southeastern New England',
#  'Marin County',
#  'Texas',
#  'Lake County']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?inputtype=textquery&key='+ gkey

# %%
# Format regions to a string
regions = str(region_df)
regions.format
# Out:
# <function str.format>

# %%
# Create an empty list to hold the region data.
place_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the regions in the list.
for i, region in enumerate(region_list):

 # Group regions in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    placeid_url = valley_url + '&input='+ region
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the region.
    print(f"Processing Record {record_count} of Set {set_count} | {region}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for each of the regions.
    try:
        # Parse the JSON and retrieve data.
        region_url = requests.get(placeid_url).json()
        # Parse out the needed data.
        place_id = region_url['candidates'][0]['place_id']
        # Append the region information into place_id_data list.
        place_id_data.append({"region": region, 
                              "Place_id": place_id})

# If an error is experienced, skip the region.
    except:
        print("region not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | Russian River Valley
# Processing Record 2 of Set 1 | Clements Hills
# Processing Record 3 of Set 1 | Temecula Valley
# Processing Record 4 of Set 1 | Columbia Valley (WA)
# Processing Record 5 of Set 1 | Nevada
# Processing Record 6 of Set 1 | Anderson Valley
# Processing Record 7 of Set 1 | Solano County
# Processing Record 8 of Set 1 | New Mexico
# Processing Record 9 of Set 1 | Sonoma County-Monterey County-Napa County
# Processing Record 10 of Set 1 | North Coast
# Processing Record 11 of Set 1 | Puget Sound
# Processing Record 12 of Set 1 | Fair Play
# Processing Record 13 of Set 1 | Rutherford
# Processing Record 14 of Set 1 | Washington
# Processing Record 15 of Set 1 | Kentucky
# Processing Record 16 of Set 1 | Sonoma County-Monterey County-Santa Barbara County
# Processing Record 17 of Set 1 | Sonoma Mountain
# Processing Record 18 of Set 1 | Monterey-Santa Barbara-Sonoma
# Processing Record 19 of Set 1 | Calaveras County
# Processing Record 20 of Set 1 | San Luis Obispo
# Processing Record 21 of Set 1 | Eola-Amity Hills
# Processing Record 22 of Set 1 | Sonoita
# Processing Record 23 of Set 1 | Napa County-Lake County
# Processing Record 24 of Set 1 | Mendocino Ridge
# Processing Record 25 of Set 1 | Yolo County
# Processing Record 1 of Set 2 | Los Carneros
# Processing Record 2 of Set 2 | Napa County
# Processing Record 3 of Set 2 | Red Hills Lake County
# region not found. Skipping...
# Processing Record 4 of Set 2 | Napa-Sonoma
# Processing Record 5 of Set 2 | Central Coast
# Processing Record 6 of Set 2 | Walla Walla Valley (WA)
# Processing Record 7 of Set 2 | Elkton Oregon
# Processing Record 8 of Set 2 | Oak Knoll District
# Processing Record 9 of Set 2 | Madera
# Processing Record 10 of Set 2 | California Other
# Processing Record 11 of Set 2 | San Antonio Valley
# Processing Record 12 of Set 2 | Ventura County
# Processing Record 13 of Set 2 | Columbia Valley-Walla Walla Valley
# Processing Record 14 of Set 2 | Santa Clara County
# Processing Record 15 of Set 2 | Chehalem Mountains
# Processing Record 16 of Set 2 | Napa Valley
# Processing Record 17 of Set 2 | Chalone
# Processing Record 18 of Set 2 | Napa-Amador
# Processing Record 19 of Set 2 | Mount Harlan
# Processing Record 20 of Set 2 | Cucamonga Valley
# Processing Record 21 of Set 2 | Horse Heaven Hills
# Processing Record 22 of Set 2 | Lake Chelan
# Processing Record 23 of Set 2 | Old Mission Peninsula
# Processing Record 24 of Set 2 | Paso Robles Willow Creek District
# Processing Record 25 of Set 2 | Oakville
# Processing Record 1 of Set 3 | Sonoma-Mendocino
# region not found. Skipping...
# Processing Record 2 of Set 3 | Finger Lakes
# Processing Record 3 of Set 3 | Mt. Harlan
# Processing Record 4 of Set 3 | Tehama County
# Processing Record 5 of Set 3 | Redwood Valley
# Processing Record 6 of Set 3 | Sonoma-Napa-Mendocino
# Processing Record 7 of Set 3 | Santa Barbara-Monterey
# region not found. Skipping...
# Processing Record 8 of Set 3 | Happy Canyon of Santa Barbara
# Processing Record 9 of Set 3 | Santa Barbara
# Processing Record 10 of Set 3 | Adelaida District
# Processing Record 11 of Set 3 | Howell Mountain
# Processing Record 12 of Set 3 | Sonoma County-San Joaquin County
# region not found. Skipping...
# Processing Record 13 of Set 3 | Rattlesnake Hills
# Processing Record 14 of Set 3 | McDowell Valley
# Processing Record 15 of Set 3 | Green Valley
# Processing Record 16 of Set 3 | Dry Creek Valley
# region not found. Skipping...
# Processing Record 17 of Set 3 | Moon Mountain District Sonoma County
# Processing Record 18 of Set 3 | San Francisco Bay
# Processing Record 19 of Set 3 | Sonoma Valley
# Processing Record 20 of Set 3 | Lake-Sonoma-Napa
# Processing Record 21 of Set 3 | Carmel Valley
# Processing Record 22 of Set 3 | Augusta
# Processing Record 23 of Set 3 | New York
# Processing Record 24 of Set 3 | Hawaii
# Processing Record 25 of Set 3 | Ribbon Ridge
# Processing Record 1 of Set 4 | El Dorado County
# Processing Record 2 of Set 4 | Napa-Sonoma-Marin
# region not found. Skipping...
# Processing Record 3 of Set 4 | Santa Margarita Ranch
# Processing Record 4 of Set 4 | Napa-Mendocino-Sonoma-Marin
# Processing Record 5 of Set 4 | Ohio
# Processing Record 6 of Set 4 | Northern Sonoma
# Processing Record 7 of Set 4 | Kelsey Bench-Lake County
# region not found. Skipping...
# Processing Record 8 of Set 4 | River Junction
# Processing Record 9 of Set 4 | Ben Lomond Mountain
# Processing Record 10 of Set 4 | Outer Coastal Plain
# region not found. Skipping...
# Processing Record 11 of Set 4 | St. Helena
# Processing Record 12 of Set 4 | Lodi
# Processing Record 13 of Set 4 | Sonoma County
# Processing Record 14 of Set 4 | Long Island
# Processing Record 15 of Set 4 | Paso Robles
# Processing Record 16 of Set 4 | San Benito County
# Processing Record 17 of Set 4 | Virginia's Eastern Shore
# Processing Record 18 of Set 4 | Ballard Canyon
# Processing Record 19 of Set 4 | El Pomar District
# Processing Record 20 of Set 4 | Cienega Valley
# Processing Record 21 of Set 4 | Chelan County
# Processing Record 22 of Set 4 | Potter Valley
# Processing Record 23 of Set 4 | Sonoma County-Santa Barbara County
# Processing Record 24 of Set 4 | Napa
# Processing Record 25 of Set 4 | Sta. Rita Hills
# Processing Record 1 of Set 5 | Cayuga Lake
# Processing Record 2 of Set 5 | Yountville
# Processing Record 3 of Set 5 | Chalk Hill
# Processing Record 4 of Set 5 | Stags Leap District
# Processing Record 5 of Set 5 | Red Mountain
# Processing Record 6 of Set 5 | Clarksburg
# Processing Record 7 of Set 5 | Massachusetts
# Processing Record 8 of Set 5 | Napa-Carneros
# Processing Record 9 of Set 5 | Alexander Valley
# Processing Record 10 of Set 5 | Edna Valley
# Processing Record 11 of Set 5 | Napa Valley-Paso Robles
# Processing Record 12 of Set 5 | Monticello
# Processing Record 13 of Set 5 | Swan Creek
# Processing Record 14 of Set 5 | South Coast
# region not found. Skipping...
# Processing Record 15 of Set 5 | Pennsylvania
# Processing Record 16 of Set 5 | Monterey-Santa Barbara
# region not found. Skipping...
# Processing Record 17 of Set 5 | Humboldt County
# Processing Record 18 of Set 5 | Sonoma
# Processing Record 19 of Set 5 | Illinois
# Processing Record 20 of Set 5 | Virginia
# Processing Record 21 of Set 5 | San Diego County
# Processing Record 22 of Set 5 | Monterey County-Napa County-Sonoma County
# Processing Record 23 of Set 5 | Grand Valley
# Processing Record 24 of Set 5 | San Lucas
# Processing Record 25 of Set 5 | Columbia Gorge (WA)
# Processing Record 1 of Set 6 | Arroyo Seco
# Processing Record 2 of Set 6 | Templeton Gap District
# Processing Record 3 of Set 6 | Placer County
# Processing Record 4 of Set 6 | Paso Robles Highlands District
# Processing Record 5 of Set 6 | Central Valley
# Processing Record 6 of Set 6 | Isle St. George
# Processing Record 7 of Set 6 | Santa Clara Valley
# Processing Record 8 of Set 6 | Sonoma County-Monterey County
# region not found. Skipping...
# Processing Record 9 of Set 6 | California-Oregon
# Processing Record 10 of Set 6 | Napa-Mendocino-Sonoma
# Processing Record 11 of Set 6 | Columbia Valley (OR)
# Processing Record 12 of Set 6 | Ancient Lakes
# Processing Record 13 of Set 6 | Yakima Valley
# Processing Record 14 of Set 6 | Atlas Peak
# Processing Record 15 of Set 6 | Polk County
# Processing Record 16 of Set 6 | Lime Kiln Valley
# Processing Record 17 of Set 6 | Malibu-Newton Canyon
# Processing Record 18 of Set 6 | Shenandoah Valley
# Processing Record 19 of Set 6 | Leelanau Peninsula
# Processing Record 20 of Set 6 | Alta Mesa
# Processing Record 21 of Set 6 | Malibu Coast
# Processing Record 22 of Set 6 | Sonoma County-Napa County
# region not found. Skipping...
# Processing Record 23 of Set 6 | Rogue Valley
# Processing Record 24 of Set 6 | El Dorado
# Processing Record 25 of Set 6 | Santa Ynez Valley
# Processing Record 1 of Set 7 | Solano County Green Valley
# Processing Record 2 of Set 7 | Temecula
# Processing Record 3 of Set 7 | Mokelumne River
# Processing Record 4 of Set 7 | Santa Lucia Highlands
# Processing Record 5 of Set 7 | Umpqua Valley
# Processing Record 6 of Set 7 | Texoma
# Processing Record 7 of Set 7 | Amador-Napa
# Processing Record 8 of Set 7 | Guenoc Valley
# Processing Record 9 of Set 7 | Santa Maria Valley
# Processing Record 10 of Set 7 | North Fork of Long Island
# Processing Record 11 of Set 7 | Washington-Oregon
# Processing Record 12 of Set 7 | Seneca Lake
# Processing Record 13 of Set 7 | Calistoga
# Processing Record 14 of Set 7 | Oregon
# Processing Record 15 of Set 7 | Naches Heights
# Processing Record 16 of Set 7 | Idaho
# Processing Record 17 of Set 7 | Coombsville
# Processing Record 18 of Set 7 | Colorado
# Processing Record 19 of Set 7 | America
# Processing Record 20 of Set 7 | New Jersey
# Processing Record 21 of Set 7 | Sonoma-Napa
# Processing Record 22 of Set 7 | Saddle Rock-Malibu
# Processing Record 23 of Set 7 | Willamette Valley
# Processing Record 24 of Set 7 | Niagara Escarpment
# Processing Record 25 of Set 7 | Lake Erie
# Processing Record 1 of Set 8 | Monterey-San Luis Obispo-Santa Barbara
# Processing Record 2 of Set 8 | Michigan
# Processing Record 3 of Set 8 | Paicines
# Processing Record 4 of Set 8 | Oregon Other
# Processing Record 5 of Set 8 | Dundee Hills
# Processing Record 6 of Set 8 | Suisun Valley
# Processing Record 7 of Set 8 | Napa County-Sonoma County-San Joaquin County
# Processing Record 8 of Set 8 | Napa County-Sonoma County
# Processing Record 9 of Set 8 | California
# Processing Record 10 of Set 8 | Napa County-Sonoma County-Lake County
# region not found. Skipping...
# Processing Record 11 of Set 8 | Lake Michigan Shore
# Processing Record 12 of Set 8 | Fort Ross-Seaview
# Processing Record 13 of Set 8 | Contra Costa County
# Processing Record 14 of Set 8 | Bennett Valley
# Processing Record 15 of Set 8 | Big Valley District-Lake County
# region not found. Skipping...
# Processing Record 16 of Set 8 | San Francisco Bay-Livermore Valley
# Processing Record 17 of Set 8 | Nevada County
# Processing Record 18 of Set 8 | Vermont
# Processing Record 19 of Set 8 | Clear Lake
# Processing Record 20 of Set 8 | Santa Cruz Mountains
# Processing Record 21 of Set 8 | Yamhill County
# Processing Record 22 of Set 8 | Mendocino County
# Processing Record 23 of Set 8 | Capay Valley
# Processing Record 24 of Set 8 | Missouri
# Processing Record 25 of Set 8 | Yadkin Valley
# Processing Record 1 of Set 9 | Cochise County
# Processing Record 2 of Set 9 | Wahluke Slope
# Processing Record 3 of Set 9 | Dunnigan Hills
# Processing Record 4 of Set 9 | Sierra Foothills
# Processing Record 5 of Set 9 | Chiles Valley
# Processing Record 6 of Set 9 | Monterey County-Napa County
# region not found. Skipping...
# Processing Record 7 of Set 9 | Southern Oregon
# Processing Record 8 of Set 9 | York Mountain
# region not found. Skipping...
# Processing Record 9 of Set 9 | Mendocino-Amador
# region not found. Skipping...
# Processing Record 10 of Set 9 | Livermore Valley
# region not found. Skipping...
# Processing Record 11 of Set 9 | Mount Veeder
# Processing Record 12 of Set 9 | High Valley
# Processing Record 13 of Set 9 | Snipes Mountain
# Processing Record 14 of Set 9 | Western Connecticut Highlands
# Processing Record 15 of Set 9 | Sierra Pelona Valley
# Processing Record 16 of Set 9 | Arizona
# Processing Record 17 of Set 9 | Pine Mountain-Cloverdale Peak
# Processing Record 18 of Set 9 | Applegate Valley
# Processing Record 19 of Set 9 | Columbia Gorge (OR)
# Processing Record 20 of Set 9 | Amador County
# Processing Record 21 of Set 9 | Lake County-Sonoma County
# Processing Record 22 of Set 9 | Santa Cruz County
# Processing Record 23 of Set 9 | Carneros-Napa Valley
# Processing Record 24 of Set 9 | Lake County-Mendocino County
# Processing Record 25 of Set 9 | The Hamptons, Long Island
# Processing Record 1 of Set 10 | Sonoma-Santa Barbara-Mendocino
# Processing Record 2 of Set 10 | Spring Mountain District
# Processing Record 3 of Set 10 | Carneros
# Processing Record 4 of Set 10 | North Carolina
# Processing Record 5 of Set 10 | Texas High Plains
# Processing Record 6 of Set 10 | Ramona Valley
# Processing Record 7 of Set 10 | Hudson River Region
# Processing Record 8 of Set 10 | Cole Ranch
# Processing Record 9 of Set 10 | Sonoma Coast
# Processing Record 10 of Set 10 | San Bernabe
# Processing Record 11 of Set 10 | Yorkville Highlands
# Processing Record 12 of Set 10 | Mendocino-Lake
# Processing Record 13 of Set 10 | Grand River Valley
# Processing Record 14 of Set 10 | McMinnville
# Processing Record 15 of Set 10 | Iowa
# Processing Record 16 of Set 10 | Sonoma County-Lake County
# Processing Record 17 of Set 10 | Santa Barbara County
# Processing Record 18 of Set 10 | Columbia Valley
# Processing Record 19 of Set 10 | Monterey-Santa Cruz
# Processing Record 20 of Set 10 | Arroyo Grande Valley
# Processing Record 21 of Set 10 | Walla Walla Valley (OR)
# Processing Record 22 of Set 10 | Antelope Valley of the California High Desert
# Processing Record 23 of Set 10 | Napa-Monterey-Mendocino
# Processing Record 24 of Set 10 | Knights Valley
# Processing Record 25 of Set 10 | Tuolumne County
# Processing Record 1 of Set 11 | Monterey
# Processing Record 2 of Set 11 | Sonoma-Napa-Lake
# Processing Record 3 of Set 11 | Mendocino
# Processing Record 4 of Set 11 | Diamond Mountain District
# Processing Record 5 of Set 11 | Middleburg
# Processing Record 6 of Set 11 | Shenandoah Valley (CA)
# Processing Record 7 of Set 11 | Rockpile
# Processing Record 8 of Set 11 | Sonoma-Napa-Monterey
# Processing Record 9 of Set 11 | Fiddletown
# Processing Record 10 of Set 11 | Mendocino-Lake County-Napa
# region not found. Skipping...
# Processing Record 11 of Set 11 | Monterey County
# Processing Record 12 of Set 11 | San Luis Obispo County
# Processing Record 13 of Set 11 | Southeastern New England
# Processing Record 14 of Set 11 | Marin County
# Processing Record 15 of Set 11 | Texas
# Processing Record 16 of Set 11 | Lake County
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create place_id dataframe
placeid_df = pd.DataFrame(place_id_data)
placeid_df.head(10)
# Out:
#                                       region                     Place_id
# 0                       Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 1                             Clements Hills  ChIJn5y8vLhKW4YRUDdxmXnvHf8
# 2                            Temecula Valley  ChIJEdB50Ih_24AR40vEqTx5JWI
# 3                       Columbia Valley (WA)  ChIJQyqk37W1RIYRnCG26gFyqjc
# 4                                     Nevada  ChIJcbTe-KEKmYARs5X8qooDR88
# 5                            Anderson Valley  ChIJa8v27oYSgYARRA6kQu3ru5s
# 6                              Solano County  ChIJB_R9n88XhYAR-L8fjKYikj0
# 7                                 New Mexico  ChIJqVKY50NQGIcRup41Yxpuv0Y
# 8  Sonoma County-Monterey County-Napa County  ChIJvZ9cEKi1RIYRurdRu42k-uk
# 9                                North Coast  ChIJ91TWEw-1RIYR-SXBulV0iyk

# %%
# Create place_id list
place_id_list = list(placeid_df['Place_id'])
place_id_list
# Out:
# ['ChIJhddrQaV7gYAR0SLRbKP8lNc',
#  'ChIJn5y8vLhKW4YRUDdxmXnvHf8',
#  'ChIJEdB50Ih_24AR40vEqTx5JWI',
#  'ChIJQyqk37W1RIYRnCG26gFyqjc',
#  'ChIJcbTe-KEKmYARs5X8qooDR88',
#  'ChIJa8v27oYSgYARRA6kQu3ru5s',
#  'ChIJB_R9n88XhYAR-L8fjKYikj0',
#  'ChIJqVKY50NQGIcRup41Yxpuv0Y',
#  'ChIJvZ9cEKi1RIYRurdRu42k-uk',
#  'ChIJ91TWEw-1RIYR-SXBulV0iyk',
#  'ChIJ4TiXsFQ-kFQRAX7WBEamkDM',
#  'ChIJhUdA46i1RIYR8bUJ_CNh_7E',
#  'ChIJPWLoDgm1RIYRFDHnU7D-Guw',
#  'ChIJ-bDD5__lhVQRuvNfbGh4QpQ',
#  'ChIJyVMZi0xzQogR_N_MxU5vH3c',
#  'ChIJ3WuezxjmjYAR17wDhRQoAkk',
#  'ChIJoenF7NCyhYARakPvDUbpQQE',
#  'ChIJvUHEkSzkjYARem7k3ShZ7lY',
#  'ChIJgQMawEWokIARUF3VYX30ANw',
#  'ChIJJ8Jse77m7IARRg_vzsKQArw',
#  'ChIJeSwhtQ9OlVQRr1RneWzpXDE',
#  'ChIJlw9tibqU1oYRLo9u4kwHPA8',
#  'ChIJWYxlsL7whIARfR_OUuFQLHQ',
#  'ChIJ67ZzfzRNgIARZVnxHr6t1E8',
#  'ChIJ69wnuncnhYAR4jxmM3iXoXE',
#  'ChIJNRmgFHlA6YAR9LRoUsOcDTs',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJOZxxaAi1RIYRe3j7KpIprWo',
#  'ChIJOZxxaAi1RIYRe3j7KpIprWo',
#  'ChIJO_fQoEsVolQR1LEd58-vxBI',
#  'ChIJk6HV2GtUwVQR5Irl6J4W7QI',
#  'ChIJn64e4Wu1RIYRGNdMhqJ5jNk',
#  'ChIJA9vG_ZILlIAREGnnItpCwzY',
#  'ChIJf5QJFBK1RIYRjjfxZz9Z0O0',
#  'ChIJP-s5hlDSkYARr2Hy9ng7dKk',
#  'ChIJqXcAstJi6YARs7DDR_CQld0',
#  'ChIJ-W5CySchQYYRgWWfn-x7feE',
#  'ChIJd_Y0eVIvkIARuQyDN0F1LBA',
#  'ChIJZznzuJsVlVQRY3ZPAz77fTk',
#  'ChIJMU8qI_lPhIARfMUQoxvSFP4',
#  'ChIJU2-BGylokoARijhqgUPyedw',
#  'ChIJV3SfjiVkXIYRFVb-fvmE_Rs',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJxe6eYrE0w4AR8OIYbSkxP_8',
#  'ChIJJSIr8a0cmFQRZIWx0ZnZtlo',
#  'ChIJiewjJFxum1QR4B1v94YWsBI',
#  'ChIJGbHcO9DVH4gRLScJopdrFhE',
#  'ChIJGeXB-Bfa7IARVfiQUCn-s6Y',
#  'ChIJf04HFA_NRIYR4BiEEOwif34',
#  'ChIJF-IKCX_p0IkRO7yA5tLMpSA',
#  'ChIJN3jyc4YakoAR3dCo-pWP7u8',
#  'ChIJ6_8ezximgoARGaPfZ5WDxqo',
#  'ChIJK-4fNG55gYARh9uaMCHzpOA',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJCcThuvUT6YARzc7brv6SLmY',
#  'ChIJ1YMtb8cU6YARSHa612Q60cg',
#  'ChIJo-5SWSjR7IARXp9cdqmlAeo',
#  'ChIJo4LFduhbhIARTBAsD475eGc',
#  'ChIJXxfbIPizWoYRIZHb2kTSBps',
#  'ChIJPT6XaW5HRYYRcaHTXsQyX98',
#  'ChIJvxRNeZOB1oYRx4K5jfKbQRE',
#  'ChIJH1iqDT2phYAROLQAfJJ_0J8',
#  'ChIJBwohpl6bj4AREMlJ8U8PlaI',
#  'ChIJI-UCgdlShIARPnjSSZd4foM',
#  'ChIJbbN3nxlbhIARBx_wpkOFTuQ',
#  'ChIJvUku7X3zjYARtkSqSWQJ2qA',
#  'ChIJQaoLFpfQ-YgR5Auq4_2K5z4',
#  'ChIJOwg_06VPwokRYv534QaPC8g',
#  'ChIJBeB5Twbb_3sRKIbMdNKCd0s',
#  'ChIJRf-SpMjORIYRYzQlL81rlqE',
#  'ChIJhQd-sopHmoARt9CBUcuaJB4',
#  'ChIJO7OVyhzx7IARKtcI0P4tfVc',
#  'ChIJ3_Uwla-uhYARAAmNhPiOav0',
#  'ChIJwY5NtXrpNogRFtmfnDlkzeU',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJ7cXYmg0HWYYRNSyRdys_2n4',
#  'ChIJwZQP0GRzU4cRaiTTgfLlAHk',
#  'ChIJ4-UsNRPi6gQRpp8ZUARPgK4',
#  'ChIJNTjFJtmhmoARRuhsu5jkrY4',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJy6Xu4VRE6IkRGA2UhmH59x0',
#  'ChIJvcTFFo_d7IAR79XMkfgilEY',
#  'ChIJ_8VcLuc7koARQXmgrXGnQxc',
#  'ChIJPTP6wnJFuokR2qI1yeXZsh4',
#  'ChIJ15UlxTFV6YAR7rCBTktGyM0',
#  'ChIJrZOHqndEE4cR4G9TwVWzjaY',
#  'ChIJ9_fr2eEZkoARE_rvkQgeKQg',
#  'ChIJVZv5TUp_m1QRmJDpy3364Ys',
#  'ChIJE73iaKRwgYARCU5su-oXmZc',
#  'ChIJOZxxaAi1RIYRe3j7KpIprWo',
#  'ChIJhSXaj5W0RIYR3V-B8qaBoa8',
#  'ChIJt82dTpwe7IAR9oK1FQs83rg',
#  'ChIJJ1DJaKmi0IkRpYVcWG3qiDM',
#  'ChIJfRoJQE1VhIARTB6YA4IIzN0',
#  'ChIJFddKXTEXhIARlHY8TOraZbY',
#  'ChIJz7o2jgm1RIYRi_5Y7JfjH0A',
#  'ChIJi5KgE2CpW4YR-pZYmMcKJf8',
#  'ChIJd37rCctnSogR4EfMcM4e6V0',
#  'ChIJ_b9z6W1l44kRHA2DVTbQxkU',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJD2TljFMUhIARBOZe4vCoE7o',
#  'ChIJIcQ99wi1RIYRDk-jP8lZ0fw',
#  'ChIJIcQ99wi1RIYRDk-jP8lZ0fw',
#  'ChIJ62zEFCeGs4kRZN9UzXYA78s',
#  'ChIJbZkJs9epz4cRVPfrCN5F4H8',
#  'ChIJieUyHiaALYgRPbQiUEchRsI',
#  'ChIJsVTwdfTf01QRfyaxfTR5OjQ',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJGSZubzgtC4gRVlkRZFCCFX8',
#  'ChIJzbK8vXDWTIgRlaZGt0lBTsA',
#  'ChIJHWD_IzDr24ARKAeA6yv9DTU',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJK0XprXRLW4YRZWyJ3baNsU0',
#  'ChIJoQjlifNKr4YRaLiiwWLfpEs',
#  'ChIJzfeI19gYllQRAdd-nffBy-E',
#  'ChIJj-yQFnNuF4cRSEKqd9QKPtg',
#  'ChIJMdXLkFlFE4cRHXwvGjutgIc',
#  'ChIJk-ZOZm4Sm4AR8eQ1nDcJNKA',
#  'ChIJLaa1-xHF7IAR93WkHTQtLZk',
#  'ChIJyZkVOx6DgoARU5w0SCOkBvY',
#  'ChIJc0hMxsz4OogRo_VKXzCAZXQ',
#  'ChIJ4Zu4Go4xjoARNcsmHfjo_dI',
#  'ChIJjUnLoHnJnIARkjPe0zv-PkA',
#  'ChIJm3RkX2m1RIYRa7ofUVcc4zQ',
#  'ChIJQyqk37W1RIYRnCG26gFyqjc',
#  'ChIJUVu5cvx4mVQRb1CuMS_kcro',
#  'ChIJtwIWxMKHl1QR30xHsvUB3dI',
#  'ChIJ1x2CKN_9hIARZkVZIna5lGo',
#  'ChIJD0-pOcNq3YgRmOvtrrA4vjg',
#  'ChIJL4EPzdHbt4kRyUilrlIwE00',
#  'ChIJPe2rmfci6IARPNp63LhdpgQ',
#  'ChIJNcZLgG_ttIkRaSyg4lb5xm4',
#  'ChIJr6p_--PfSk0RK-iQseQeI6Q',
#  'ChIJ8WejwhXZQIYRwKRHGSX22W0',
#  'ChIJP9YI-akd6IARWozqsnEtt5M',
#  'ChIJg3cxDPaHxVQRde0DiGnDILs',
#  'ChIJMW6HHQrLRIYRGYgJdE4dGwI',
#  'ChIJH3v79pZT6YAR-MXTvZmd134',
#  'ChIJHWTSAsMRhYAR7nqXk1q6deI',
#  'ChIJI74a9VJi24ARqAY4oIgOvGg',
#  'ChIJ_fI5LWWsmoARS-gGEa8EBG0',
#  'ChIJY2jxLkBukoARNMBojauvJF8',
#  'ChIJsUP3Td8ixFQRyE51ASKNrd0',
#  'ChIJU06mbyZpS4YRaxZrJLN9aSY',
#  'ChIJV3SfjiVkXIYRFVb-fvmE_Rs',
#  'ChIJiXWJGHVmhIARgRDJUsHC0z8',
#  'ChIJOZxxaAi1RIYRe3j7KpIprWo',
#  'ChIJHf28GvKL6IkRjrVcO0U2CJg',
#  'ChIJ58L9WshnlVQRK_Ybl-Gu9TM',
#  'ChIJZaOyhSfs0IkR7MRQ5ZLpRyQ',
#  'ChIJkTJxhwlDhIARQO6YM2Hiiwc',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJyUnptFdil1QRG49Wjiuz6eY',
#  'ChIJ6Znkhaj_WFMRWIf3FQUwa9A',
#  'ChIJrQB7dGgGhYARh1UG9UP-YFs',
#  'ChIJt1YYm3QUQIcR_6eQSTGDVMc',
#  'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#  'ChIJn0AAnpX7wIkRjW0_-Ad70iw',
#  'ChIJd517gUOshYARReDmDiHtgAM',
#  'ChIJvcCvpxEj6IARX8hjBiy24HQ',
#  'ChIJbezwJP6hlVQRBDL4exvIWSo',
#  'ChIJ12YMXUm0AogRkMoAelhilAA',
#  'ChIJHYh0Ax3eMYgRYsbdqpOpRfM',
#  'ChIJX726TTvkjYAREIEk3qFtclM',
#  'ChIJEQTKxz2qTE0Rs8liellI3Zc',
#  'ChIJYdTTrR0YkoARQcfiJ6VNmXc',
#  'ChIJVWqfm3xuk1QRdrgLettlTH0',
#  'ChIJQyfp5wm1RIYRd7IXfFuFzTg',
#  'ChIJwWWZ5GwRhYARtCTlQhqqAeg',
#  'ChIJ31ZZ5gY-kIAR0dtYpsEqJEc',
#  'ChIJj7atfV0ihIAR_qYnBSATSUk',
#  'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#  'ChIJbWjISvi2EIgR-XXUbfv_U1k',
#  'ChIJqScrY5WkhoARlNUv2wg3tsA',
#  'ChIJ3QQ6ifNuhYAR4fM4Ln-yyVk',
#  'ChIJKzh9MGNIhIARECiBFxnNZt8',
#  'ChIJZQ5HN8Hnj4ARYsA5YnxIMuc',
#  'ChIJX_aX8TOFm4ARgtETUAvolo8',
#  'ChIJ_87aSGzctEwRtGtUNnSJTSY',
#  'ChIJo0BOeojtg4ARIxa_m15L_1A',
#  'ChIJV7FWSmU7joARrCMjR_-QG_4',
#  'ChIJ38wjXU1KlVQRnXojmjNOBBE',
#  'ChIJh-hRvjCOgYARFQFu8mmzZyM',
#  'ChIJP5PWeHDphIARy2FLJhKIJjc',
#  'ChIJfeMiSNXmwIcRcr1mBFnEW7U',
#  'ChIJd0x0EUEeUYgRH2PjRdOWPwc',
#  'ChIJ30PnwuKo14YRUhvNr6Cpals',
#  'ChIJV96zdT2umVQRoqO1RPkJ1JU',
#  'ChIJ-xA8jVDAhIARYOH-hhbSx24',
#  'ChIJS6NrAai1RIYRJWf-bmJ8Eaw',
#  'ChIJA5vomRzLRIYRd4u7z-L03go',
#  'ChIJffBbhegNxlQRyq1bp4KiPOY',
#  'ChIJE2iH7ldThIARzLXbwsD5C8w',
#  'ChIJ_5yK1dFjWoYRLfOIN4fz3dg',
#  'ChIJ3WW0OJ0jmFQRmvZ-oWS-6iQ',
#  'ChIJjTbUpWv_54kR1Kq8EXgm4T0',
#  'ChIJmUlcX5OKwoARog_bRXgdajw',
#  'ChIJaxhMy-sIK4cRcc3Bf7EnOUI',
#  'ChIJB9lyfRj5g4ARblOcfrmkRrg',
#  'ChIJjV18y1V9xVQRNey4WKdjfrs',
#  'ChIJzfeI19gYllQRAdd-nffBy-E',
#  'ChIJo-0fEllAmoAReviEN7sDX08',
#  'ChIJkRamZgi1RIYRunh_5JKEl1Y',
#  'ChIJfzsx1n8TjoARGbNHDCbAPhU',
#  'ChIJ6_h3N-AHhYARlez7x1w_DXI',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJG6mpkc6V6IkRUWCATXOJAbw',
#  'ChIJDYp1OaiuhYARIwCuBhIwVOs',
#  'ChIJ5e4J-wi1RIYR0VuNKIr8jbs',
#  'ChIJc91fIoDbRIYR_iZWpJpCMiE',
#  'ChIJgRo4_MQfVIgRGa4i6fUwP60',
#  'ChIJj4-JMpIA_YYRHAbk1BKKwbQ',
#  'ChIJUdAfj5Do24ARv5f06-88kuU',
#  'ChIJ7xaFp4e1RIYRUDa60WcaeWI',
#  'ChIJRYqyEU4xW4YR56RjEb-M_w0',
#  'ChIJB8Hkg3mehoARNDJoq9RCScI',
#  'ChIJ3SmLUNGWYoYRGDGqnmIwOPo',
#  'ChIJ7ZPooopagYAR9n4U4o9Jyqk',
#  'ChIJT5My3mN7gYARReyRyHp9jrk',
#  'ChIJm3RkX2m1RIYRa7ofUVcc4zQ',
#  'ChIJo3PJF7dOlVQRSM9F2xtwRMo',
#  'ChIJGWD48W9e7ocR2VnHV0pj78Y',
#  'ChIJ3Qfw6jZVgYAR6v6_SxmR4cc',
#  'ChIJXxfrQWYM7IAR_9ACRVau1Wo',
#  'ChIJIcQ99wi1RIYRDk-jP8lZ0fw',
#  'ChIJSdU2fBtEjoARhfnXKksQylI',
#  'ChIJZSOdUFdZ7IAREjbaeUVyxmU',
#  'ChIJBwOnamNqolQRlUFeGjkeZrc',
#  'ChIJA3cgzNJDwoARX6xdvBafiAU',
#  'ChIJC_EH0CPkjYARQvIZ23xl6MY',
#  'ChIJqe38AQa1RIYRh8jExRIRmZc',
#  'ChIJUXsaVaYxl4ARpyB7IpcuWGU',
#  'ChIJkfu1cFLkjYARXj1K2AlJSO4',
#  'ChIJUWVAwmcGhYARBoANHIv70Os',
#  'ChIJM-tWPGuygYARO7PAQfKXD9Y',
#  'ChIJ2blEOUO7nYARLzTrfw18ILU',
#  'ChIJVWHbyXtttokRI_r_3GdeZaA',
#  'ChIJJ25lpCtnmoARSRe6Bmrznkg',
#  'ChIJyyaMKuUcW4YR1JISPgJLcKM',
#  'ChIJzxdcDVrkjYARzccwwfdSQsg',
#  'ChIJr2rpnolmmoARXFxc3qp4ks4',
#  'ChIJUV7XWK6z7IARFNInOyD3gBc',
#  'ChIJX3PwOP2E7IAR9ToVLk_oEGY',
#  'ChIJpZX7V4BL5IkR4arfG9Insgw',
#  'ChIJ82aOMnyhhYARHLRVUdyH0As',
#  'ChIJSTKCCzZwQIYRPN4IGI8c6xY',
#  'ChIJKdUvmscAD4gRZsVGNFFqkhs']

# %%
# Target valley
#region = "Sonoma Valley"

# Build the endpoint URL
valley_url2 = ('https://maps.googleapis.com/maps/api/place/details/json?&key='+ gkey)

# %%
# Create an empty list to hold the coord data.
coord_id_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the place ids in the list.
for i, placeids in enumerate(place_id_list):

 # Group place ids in sets of 25 for logging purposes.
    if (i % 25 == 0 and i >= 25):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each region_id.
    coord_url = valley_url2 + '&place_id='+ placeids
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the place ids.
    print(f"Processing Record {record_count} of Set {set_count} | {placeids}")
    # Add 1 to the record count.
    record_count += 1 
    
# Run an API request for the place ids and retrieve the lat long info.
    try:
        # Parse the JSON and retrieve data.
        geo_url = requests.get(coord_url).json()
        # Parse out the needed data.
        lat_id = geo_url['result']['geometry']['location']['lat']
        long_id = geo_url['result']['geometry']['location']['lng']
        # Append the region information into place_id_data list.
        coord_id_data.append({"Place_id": placeids, 
                              "Latitude": lat_id,
                             "Longitude": long_id})
        


# If an error is experienced, skip the record.
    except:
        print("record not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ChIJhddrQaV7gYAR0SLRbKP8lNc
# Processing Record 2 of Set 1 | ChIJn5y8vLhKW4YRUDdxmXnvHf8
# Processing Record 3 of Set 1 | ChIJEdB50Ih_24AR40vEqTx5JWI
# Processing Record 4 of Set 1 | ChIJQyqk37W1RIYRnCG26gFyqjc
# Processing Record 5 of Set 1 | ChIJcbTe-KEKmYARs5X8qooDR88
# Processing Record 6 of Set 1 | ChIJa8v27oYSgYARRA6kQu3ru5s
# Processing Record 7 of Set 1 | ChIJB_R9n88XhYAR-L8fjKYikj0
# Processing Record 21 of Set 9 | ChIJo3PJF7dOlVQRSM9F2xtwRMo
# Processing Record 22 of Set 9 | ChIJGWD48W9e7ocR2VnHV0pj78Y
# Processing Record 23 of Set 9 | ChIJ3Qfw6jZVgYAR6v6_SxmR4cc
# Processing Record 24 of Set 9 | ChIJXxfrQWYM7IAR_9ACRVau1Wo
# Processing Record 25 of Set 9 | ChIJIcQ99wi1RIYRDk-jP8lZ0fw
# Processing Record 1 of Set 10 | ChIJSdU2fBtEjoARhfnXKksQylI
# Processing Record 2 of Set 10 | ChIJZSOdUFdZ7IAREjbaeUVyxmU
# Processing Record 3 of Set 10 | ChIJBwOnamNqolQRlUFeGjkeZrc
# Processing Record 4 of Set 10 | ChIJA3cgzNJDwoARX6xdvBafiAU
# Processing Record 5 of Set 10 | ChIJC_EH0CPkjYARQvIZ23xl6MY
# Processing Record 6 of Set 10 | ChIJqe38AQa1RIYRh8jExRIRmZc
# Processing Record 7 of Set 10 | ChIJUXsaVaYxl4ARpyB7IpcuWGU
# Processing Record 8 of Set 10 | ChIJkfu1cFLkjYARXj1K2AlJSO4
# Processing Record 9 of Set 10 | ChIJUWVAwmcGhYARBoANHIv70Os
# Processing Record 10 of Set 10 | ChIJM-tWPGuygYARO7PAQfKXD9Y
# Processing Record 11 of Set 10 | ChIJ2blEOUO7nYARLzTrfw18ILU
# Processing Record 12 of Set 10 | ChIJVWHbyXtttokRI_r_3GdeZaA
# Processing Record 13 of Set 10 | ChIJJ25lpCtnmoARSRe6Bmrznkg
# Processing Record 14 of Set 10 | ChIJyyaMKuUcW4YR1JISPgJLcKM
# Processing Record 15 of Set 10 | ChIJzxdcDVrkjYARzccwwfdSQsg
# Processing Record 16 of Set 10 | ChIJr2rpnolmmoARXFxc3qp4ks4
# Processing Record 17 of Set 10 | ChIJUV7XWK6z7IARFNInOyD3gBc
# Processing Record 18 of Set 10 | ChIJX3PwOP2E7IAR9ToVLk_oEGY
# Processing Record 19 of Set 10 | ChIJpZX7V4BL5IkR4arfG9Insgw
# Processing Record 20 of Set 10 | ChIJ82aOMnyhhYARHLRVUdyH0As
# Processing Record 21 of Set 10 | ChIJSTKCCzZwQIYRPN4IGI8c6xY
# Processing Record 22 of Set 10 | ChIJKdUvmscAD4gRZsVGNFFqkhs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a coordinate dataframe
coord_df = pd.DataFrame(coord_id_data)
coord_df.head(10)
# Out:
#                       Place_id   Latitude   Longitude
# 0  ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# 1  ChIJn5y8vLhKW4YRUDdxmXnvHf8  30.271982  -97.800297
# 2  ChIJEdB50Ih_24AR40vEqTx5JWI  33.473917 -117.140587
# 3  ChIJQyqk37W1RIYRnCG26gFyqjc  30.282339  -97.742903
# 4  ChIJcbTe-KEKmYARs5X8qooDR88  38.802610 -116.419389
# 5  ChIJa8v27oYSgYARRA6kQu3ru5s  39.086566 -123.479454
# 6  ChIJB_R9n88XhYAR-L8fjKYikj0  38.310497 -121.901795
# 7  ChIJqVKY50NQGIcRup41Yxpuv0Y  34.519940 -105.870090
# 8  ChIJvZ9cEKi1RIYRurdRu42k-uk  30.263664  -97.740859
# 9  ChIJ91TWEw-1RIYR-SXBulV0iyk  30.265789  -97.748916

# %%
# Join the place_id and coord dataframes
region_df = pd.concat([placeid_df, coord_df], axis=1, join="inner")
    
region_df
# Out:
#                        region                     Place_id  \
# 0        Russian River Valley  ChIJhddrQaV7gYAR0SLRbKP8lNc
# 1              Clements Hills  ChIJn5y8vLhKW4YRUDdxmXnvHf8
# 2             Temecula Valley  ChIJEdB50Ih_24AR40vEqTx5JWI
# 3        Columbia Valley (WA)  ChIJQyqk37W1RIYRnCG26gFyqjc
# 4                      Nevada  ChIJcbTe-KEKmYARs5X8qooDR88
# ..                        ...                          ...
# 242    San Luis Obispo County  ChIJX3PwOP2E7IAR9ToVLk_oEGY
# 243  Southeastern New England  ChIJpZX7V4BL5IkR4arfG9Insgw
# 244              Marin County  ChIJ82aOMnyhhYARHLRVUdyH0As
# 245                     Texas  ChIJSTKCCzZwQIYRPN4IGI8c6xY
# 246               Lake County  ChIJKdUvmscAD4gRZsVGNFFqkhs
#
#                         Place_id   Latitude   Longitude
# 0    ChIJhddrQaV7gYAR0SLRbKP8lNc  38.911980 -123.053708
# 1    ChIJn5y8vLhKW4YRUDdxmXnvHf8  30.271982  -97.800297
# 2    ChIJEdB50Ih_24AR40vEqTx5JWI  33.473917 -117.140587
# 3    ChIJQyqk37W1RIYRnCG26gFyqjc  30.282339  -97.742903
# 4    ChIJcbTe-KEKmYARs5X8qooDR88  38.802610 -116.419389
# ..                           ...        ...         ...
# 242  ChIJX3PwOP2E7IAR9ToVLk_oEGY  35.310230 -120.435763
# 243  ChIJpZX7V4BL5IkR4arfG9Insgw  41.698581  -71.479685
# 244  ChIJ82aOMnyhhYARHLRVUdyH0As  38.083403 -122.763304
# 245  ChIJSTKCCzZwQIYRPN4IGI8c6xY  31.968599  -99.901813
# 246  ChIJKdUvmscAD4gRZsVGNFFqkhs  42.368936  -87.827153
#
# [247 rows x 5 columns]

# %%
# Drop Place_id column
region_df = region_df.drop(['Place_id'], axis=1)
region_df
# Out:
#                        region   Latitude   Longitude
# 0        Russian River Valley  38.911980 -123.053708
# 1              Clements Hills  30.271982  -97.800297
# 2             Temecula Valley  33.473917 -117.140587
# 3        Columbia Valley (WA)  30.282339  -97.742903
# 4                      Nevada  38.802610 -116.419389
# ..                        ...        ...         ...
# 242    San Luis Obispo County  35.310230 -120.435763
# 243  Southeastern New England  41.698581  -71.479685
# 244              Marin County  38.083403 -122.763304
# 245                     Texas  31.968599  -99.901813
# 246               Lake County  42.368936  -87.827153
#
# [247 rows x 3 columns]

# %%
# Create connection string
db_string = f"postgresql+psycopg2://postgres:" + password + "@127.0.0.1:5432/WineEnthusiast"

# %%
# Create the database engine
engine = create_engine(db_string)

# %%
# Save the region_df DataFrame to a SQL table called wineregions
region_df.to_sql(name='wineregions', con=engine)

# %%
region_df.to_csv("Data/region_df.csv", index=False)
